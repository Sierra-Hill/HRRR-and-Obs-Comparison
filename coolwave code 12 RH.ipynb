# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# For some reason the 12 hour forecast RH file has NaN after the first 4 days. Only way to fix that is go into Moba and redo the file starting with collecting the data from the HRRR, then converting the grib to nc and then putting them into csv, then transform the csv file so that it works with the existing code

# %%
#load model data
hrrrtmp00=pd.read_csv(r"C:\Users\sierra\Downloads\thrrrRH00.csv")
hrrrtmp06=pd.read_csv(r"C:\Users\sierra\Downloads\thrrrRH06.csv")
hrrrtmp12=pd.read_csv(r"C:\Users\sierra\Downloads\thrrrRH12 (1).csv")
hrrrtmp18=pd.read_csv(r"C:\Users\sierra\Downloads\thrrrRH18.csv")

# %%
#adds a datetime index to the pandas dataframe
timeindex = pd.date_range(start='2024-06-01',end='2024-08-31-23', freq='H')
hrrrtmp00.index=timeindex
hrrrtmp06.index=timeindex
hrrrtmp12.index=timeindex
hrrrtmp18.index=timeindex

# %%
fcst00hour00=hrrrtmp00.at_time('00:00:00')
fcst00hour01=hrrrtmp00.at_time('1:00:00')
fcst00hour02=hrrrtmp00.at_time('2:00:00')
fcst00hour03=hrrrtmp00.at_time('3:00:00')
fcst00hour04=hrrrtmp00.at_time('4:00:00')
fcst00hour05=hrrrtmp00.at_time('5:00:00')
fcst00hour06=hrrrtmp00.at_time('6:00:00')
fcst00hour07=hrrrtmp00.at_time('7:00:00')
fcst00hour08=hrrrtmp00.at_time('8:00:00')
fcst00hour09=hrrrtmp00.at_time('9:00:00')
fcst00hour10=hrrrtmp00.at_time('10:00:00')
fcst00hour11=hrrrtmp00.at_time('11:00:00')
fcst00hour12=hrrrtmp00.at_time('12:00:00')
fcst00hour13=hrrrtmp00.at_time('13:00:00')
fcst00hour14=hrrrtmp00.at_time('14:00:00')
fcst00hour15=hrrrtmp00.at_time('15:00:00')
fcst00hour16=hrrrtmp00.at_time('16:00:00')
fcst00hour17=hrrrtmp00.at_time('17:00:00')
fcst00hour18=hrrrtmp00.at_time('18:00:00')
fcst00hour19=hrrrtmp00.at_time('19:00:00')
fcst00hour20=hrrrtmp00.at_time('20:00:00')
fcst00hour21=hrrrtmp00.at_time('21:00:00')
fcst00hour22=hrrrtmp00.at_time('22:00:00')
fcst00hour23=hrrrtmp00.at_time('23:00:00')

# %%
fcst06hour00=hrrrtmp06.at_time('00:00:00')
fcst06hour01=hrrrtmp06.at_time('1:00:00')
fcst06hour02=hrrrtmp06.at_time('2:00:00')
fcst06hour03=hrrrtmp06.at_time('3:00:00')
fcst06hour04=hrrrtmp06.at_time('4:00:00')
fcst06hour05=hrrrtmp06.at_time('5:00:00')
fcst06hour06=hrrrtmp06.at_time('6:00:00')
fcst06hour07=hrrrtmp06.at_time('7:00:00')
fcst06hour08=hrrrtmp06.at_time('8:00:00')
fcst06hour09=hrrrtmp06.at_time('9:00:00')
fcst06hour10=hrrrtmp06.at_time('10:00:00')
fcst06hour11=hrrrtmp06.at_time('11:00:00')
fcst06hour12=hrrrtmp06.at_time('12:00:00')
fcst06hour13=hrrrtmp06.at_time('13:00:00')
fcst06hour14=hrrrtmp06.at_time('14:00:00')
fcst06hour15=hrrrtmp06.at_time('15:00:00')
fcst06hour16=hrrrtmp06.at_time('16:00:00')
fcst06hour17=hrrrtmp06.at_time('17:00:00')
fcst06hour18=hrrrtmp06.at_time('18:00:00')
fcst06hour19=hrrrtmp06.at_time('19:00:00')
fcst06hour20=hrrrtmp06.at_time('20:00:00')
fcst06hour21=hrrrtmp06.at_time('21:00:00')
fcst06hour22=hrrrtmp06.at_time('22:00:00')
fcst06hour23=hrrrtmp06.at_time('23:00:00')

# %%
fcst12hour00=hrrrtmp12.at_time('00:00:00')
fcst12hour01=hrrrtmp12.at_time('1:00:00')
fcst12hour02=hrrrtmp12.at_time('2:00:00')
fcst12hour03=hrrrtmp12.at_time('3:00:00')
fcst12hour04=hrrrtmp12.at_time('4:00:00')
fcst12hour05=hrrrtmp12.at_time('5:00:00')
fcst12hour06=hrrrtmp12.at_time('6:00:00')
fcst12hour07=hrrrtmp12.at_time('7:00:00')
fcst12hour08=hrrrtmp12.at_time('8:00:00')
fcst12hour09=hrrrtmp12.at_time('9:00:00')
fcst12hour10=hrrrtmp12.at_time('10:00:00')
fcst12hour11=hrrrtmp12.at_time('11:00:00')
fcst12hour12=hrrrtmp12.at_time('12:00:00')
fcst12hour13=hrrrtmp12.at_time('13:00:00')
fcst12hour14=hrrrtmp12.at_time('14:00:00')
fcst12hour15=hrrrtmp12.at_time('15:00:00')
fcst12hour16=hrrrtmp12.at_time('16:00:00')
fcst12hour17=hrrrtmp12.at_time('17:00:00')
fcst12hour18=hrrrtmp12.at_time('18:00:00')
fcst12hour19=hrrrtmp12.at_time('19:00:00')
fcst12hour20=hrrrtmp12.at_time('20:00:00')
fcst12hour21=hrrrtmp12.at_time('21:00:00')
fcst12hour22=hrrrtmp12.at_time('22:00:00')
fcst12hour23=hrrrtmp12.at_time('23:00:00')

# %%
fcst18hour00=hrrrtmp18.at_time('00:00:00')
fcst18hour01=hrrrtmp18.at_time('1:00:00')
fcst18hour02=hrrrtmp18.at_time('2:00:00')
fcst18hour03=hrrrtmp18.at_time('3:00:00')
fcst18hour04=hrrrtmp18.at_time('4:00:00')
fcst18hour05=hrrrtmp18.at_time('5:00:00')
fcst18hour06=hrrrtmp18.at_time('6:00:00')
fcst18hour07=hrrrtmp18.at_time('7:00:00')
fcst18hour08=hrrrtmp18.at_time('8:00:00')
fcst18hour09=hrrrtmp18.at_time('9:00:00')
fcst18hour10=hrrrtmp18.at_time('10:00:00')
fcst18hour11=hrrrtmp18.at_time('11:00:00')
fcst18hour12=hrrrtmp18.at_time('12:00:00')
fcst18hour13=hrrrtmp18.at_time('13:00:00')
fcst18hour14=hrrrtmp18.at_time('14:00:00')
fcst18hour15=hrrrtmp18.at_time('15:00:00')
fcst18hour16=hrrrtmp18.at_time('16:00:00')
fcst18hour17=hrrrtmp18.at_time('17:00:00')
fcst18hour18=hrrrtmp18.at_time('18:00:00')
fcst18hour19=hrrrtmp18.at_time('19:00:00')
fcst18hour20=hrrrtmp18.at_time('20:00:00')
fcst18hour21=hrrrtmp18.at_time('21:00:00')
fcst18hour22=hrrrtmp18.at_time('22:00:00')
fcst18hour23=hrrrtmp18.at_time('23:00:00')

# %%
fcst00hour00urban = (fcst00hour00['0'] + fcst00hour00['1'] + fcst00hour00['2'] + fcst00hour00['4'] + fcst00hour00['9'] + fcst00hour00['10'] + fcst00hour00['13'] + fcst00hour00['14']) / 8
fcst06hour00urban = (fcst06hour00['0'] + fcst06hour00['1'] + fcst06hour00['2'] + fcst06hour00['4'] + fcst06hour00['9'] + fcst06hour00['10'] + fcst06hour00['13'] + fcst06hour00['14']) / 8
fcst12hour00urban = (fcst12hour00['0'] + fcst12hour00['1'] + fcst12hour00['2'] + fcst12hour00['4'] + fcst12hour00['9'] + fcst12hour00['10'] + fcst12hour00['13'] + fcst12hour00['14']) / 8
fcst18hour00urban = (fcst18hour00['0'] + fcst18hour00['1'] + fcst18hour00['2'] + fcst18hour00['4'] + fcst18hour00['9'] + fcst18hour00['10'] + fcst18hour00['13'] + fcst18hour00['14']) / 8

fcst00hour01urban = (fcst00hour01['0'] + fcst00hour01['1'] + fcst00hour01['2'] + fcst00hour01['4'] + fcst00hour01['9'] + fcst00hour01['10'] + fcst00hour01['13'] + fcst00hour01['14']) / 8
fcst06hour01urban = (fcst06hour01['0'] + fcst06hour01['1'] + fcst06hour01['2'] + fcst06hour01['4'] + fcst06hour01['9'] + fcst06hour01['10'] + fcst06hour01['13'] + fcst06hour01['14']) / 8
fcst12hour01urban = (fcst12hour01['0'] + fcst12hour01['1'] + fcst12hour01['2'] + fcst12hour01['4'] + fcst12hour01['9'] + fcst12hour01['10'] + fcst12hour01['13'] + fcst12hour01['14']) / 8
fcst18hour01urban = (fcst18hour01['0'] + fcst18hour01['1'] + fcst18hour01['2'] + fcst18hour01['4'] + fcst18hour01['9'] + fcst18hour01['10'] + fcst18hour01['13'] + fcst18hour01['14']) / 8

fcst00hour02urban = (fcst00hour02['0'] + fcst00hour02['1'] + fcst00hour02['2'] + fcst00hour02['4'] + fcst00hour02['9'] + fcst00hour02['10'] + fcst00hour02['13'] + fcst00hour02['14']) / 8
fcst06hour02urban = (fcst06hour02['0'] + fcst06hour02['1'] + fcst06hour02['2'] + fcst06hour02['4'] + fcst06hour02['9'] + fcst06hour02['10'] + fcst06hour02['13'] + fcst06hour02['14']) / 8
fcst12hour02urban = (fcst12hour02['0'] + fcst12hour02['1'] + fcst12hour02['2'] + fcst12hour02['4'] + fcst12hour02['9'] + fcst12hour02['10'] + fcst12hour02['13'] + fcst12hour02['14']) / 8
fcst18hour02urban = (fcst18hour02['0'] + fcst18hour02['1'] + fcst18hour02['2'] + fcst18hour02['4'] + fcst18hour02['9'] + fcst18hour02['10'] + fcst18hour02['13'] + fcst18hour02['14']) / 8

fcst00hour03urban = (fcst00hour03['0'] + fcst00hour03['1'] + fcst00hour03['2'] + fcst00hour03['4'] + fcst00hour03['9'] + fcst00hour03['10'] + fcst00hour03['13'] + fcst00hour03['14']) / 8
fcst06hour03urban = (fcst06hour03['0'] + fcst06hour03['1'] + fcst06hour03['2'] + fcst06hour03['4'] + fcst06hour03['9'] + fcst06hour03['10'] + fcst06hour03['13'] + fcst06hour03['14']) / 8
fcst12hour03urban = (fcst12hour03['0'] + fcst12hour03['1'] + fcst12hour03['2'] + fcst12hour03['4'] + fcst12hour03['9'] + fcst12hour03['10'] + fcst12hour03['13'] + fcst12hour03['14']) / 8
fcst18hour03urban = (fcst18hour03['0'] + fcst18hour03['1'] + fcst18hour03['2'] + fcst18hour03['4'] + fcst18hour03['9'] + fcst18hour03['10'] + fcst18hour03['13'] + fcst18hour03['14']) / 8

fcst00hour04urban = (fcst00hour04['0'] + fcst00hour04['1'] + fcst00hour04['2'] + fcst00hour04['4'] + fcst00hour04['9'] + fcst00hour04['10'] + fcst00hour04['13'] + fcst00hour04['14']) / 8
fcst06hour04urban = (fcst06hour04['0'] + fcst06hour04['1'] + fcst06hour04['2'] + fcst06hour04['4'] + fcst06hour04['9'] + fcst06hour04['10'] + fcst06hour04['13'] + fcst06hour04['14']) / 8
fcst12hour04urban = (fcst12hour04['0'] + fcst12hour04['1'] + fcst12hour04['2'] + fcst12hour04['4'] + fcst12hour04['9'] + fcst12hour04['10'] + fcst12hour04['13'] + fcst12hour04['14']) / 8
fcst18hour04urban = (fcst18hour04['0'] + fcst18hour04['1'] + fcst18hour04['2'] + fcst18hour04['4'] + fcst18hour04['9'] + fcst18hour04['10'] + fcst18hour04['13'] + fcst18hour04['14']) / 8

fcst00hour05urban = (fcst00hour05['0'] + fcst00hour05['1'] + fcst00hour05['2'] + fcst00hour05['4'] + fcst00hour05['9'] + fcst00hour05['10'] + fcst00hour05['13'] + fcst00hour05['14']) / 8
fcst06hour05urban = (fcst06hour05['0'] + fcst06hour05['1'] + fcst06hour05['2'] + fcst06hour05['4'] + fcst06hour05['9'] + fcst06hour05['10'] + fcst06hour05['13'] + fcst06hour05['14']) / 8
fcst12hour05urban = (fcst12hour05['0'] + fcst12hour05['1'] + fcst12hour05['2'] + fcst12hour05['4'] + fcst12hour05['9'] + fcst12hour05['10'] + fcst12hour05['13'] + fcst12hour05['14']) / 8
fcst18hour05urban = (fcst18hour05['0'] + fcst18hour05['1'] + fcst18hour05['2'] + fcst18hour05['4'] + fcst18hour05['9'] + fcst18hour05['10'] + fcst18hour05['13'] + fcst18hour05['14']) / 8

fcst00hour06urban = (fcst00hour06['0'] + fcst00hour06['1'] + fcst00hour06['2'] + fcst00hour06['4'] + fcst00hour06['9'] + fcst00hour06['10'] + fcst00hour06['13'] + fcst00hour06['14']) / 8
fcst06hour06urban = (fcst06hour06['0'] + fcst06hour06['1'] + fcst06hour06['2'] + fcst06hour06['4'] + fcst06hour06['9'] + fcst06hour06['10'] + fcst06hour06['13'] + fcst06hour06['14']) / 8
fcst12hour06urban = (fcst12hour06['0'] + fcst12hour06['1'] + fcst12hour06['2'] + fcst12hour06['4'] + fcst12hour06['9'] + fcst12hour06['10'] + fcst12hour06['13'] + fcst12hour06['14']) / 8
fcst18hour06urban = (fcst18hour06['0'] + fcst18hour06['1'] + fcst18hour06['2'] + fcst18hour06['4'] + fcst18hour06['9'] + fcst18hour06['10'] + fcst18hour06['13'] + fcst18hour06['14']) / 8

fcst00hour07urban = (fcst00hour07['0'] + fcst00hour07['1'] + fcst00hour07['2'] + fcst00hour07['4'] + fcst00hour07['9'] + fcst00hour07['10'] + fcst00hour07['13'] + fcst00hour07['14']) / 8
fcst06hour07urban = (fcst06hour07['0'] + fcst06hour07['1'] + fcst06hour07['2'] + fcst06hour07['4'] + fcst06hour07['9'] + fcst06hour07['10'] + fcst06hour07['13'] + fcst06hour07['14']) / 8
fcst12hour07urban = (fcst12hour07['0'] + fcst12hour07['1'] + fcst12hour07['2'] + fcst12hour07['4'] + fcst12hour07['9'] + fcst12hour07['10'] + fcst12hour07['13'] + fcst12hour07['14']) / 8
fcst18hour07urban = (fcst18hour07['0'] + fcst18hour07['1'] + fcst18hour07['2'] + fcst18hour07['4'] + fcst18hour07['9'] + fcst18hour07['10'] + fcst18hour07['13'] + fcst18hour07['14']) / 8

fcst00hour08urban = (fcst00hour08['0'] + fcst00hour08['1'] + fcst00hour08['2'] + fcst00hour08['4'] + fcst00hour08['9'] + fcst00hour08['10'] + fcst00hour08['13'] + fcst00hour08['14']) / 8
fcst06hour08urban = (fcst06hour08['0'] + fcst06hour08['1'] + fcst06hour08['2'] + fcst06hour08['4'] + fcst06hour08['9'] + fcst06hour08['10'] + fcst06hour08['13'] + fcst06hour08['14']) / 8
fcst12hour08urban = (fcst12hour08['0'] + fcst12hour08['1'] + fcst12hour08['2'] + fcst12hour08['4'] + fcst12hour08['9'] + fcst12hour08['10'] + fcst12hour08['13'] + fcst12hour08['14']) / 8
fcst18hour08urban = (fcst18hour08['0'] + fcst18hour08['1'] + fcst18hour08['2'] + fcst18hour08['4'] + fcst18hour08['9'] + fcst18hour08['10'] + fcst18hour08['13'] + fcst18hour08['14']) / 8

fcst00hour09urban = (fcst00hour09['0'] + fcst00hour09['1'] + fcst00hour09['2'] + fcst00hour09['4'] + fcst00hour09['9'] + fcst00hour09['10'] + fcst00hour09['13'] + fcst00hour09['14']) / 8
fcst06hour09urban = (fcst06hour09['0'] + fcst06hour09['1'] + fcst06hour09['2'] + fcst06hour09['4'] + fcst06hour09['9'] + fcst06hour09['10'] + fcst06hour09['13'] + fcst06hour09['14']) / 8
fcst12hour09urban = (fcst12hour09['0'] + fcst12hour09['1'] + fcst12hour09['2'] + fcst12hour09['4'] + fcst12hour09['9'] + fcst12hour09['10'] + fcst12hour09['13'] + fcst12hour09['14']) / 8
fcst18hour09urban = (fcst18hour09['0'] + fcst18hour09['1'] + fcst18hour09['2'] + fcst18hour09['4'] + fcst18hour09['9'] + fcst18hour09['10'] + fcst18hour09['13'] + fcst18hour09['14']) / 8

fcst00hour10urban = (fcst00hour10['0'] + fcst00hour10['1'] + fcst00hour10['2'] + fcst00hour10['4'] + fcst00hour10['9'] + fcst00hour10['10'] + fcst00hour10['13'] + fcst00hour10['14']) / 8
fcst06hour10urban = (fcst06hour10['0'] + fcst06hour10['1'] + fcst06hour10['2'] + fcst06hour10['4'] + fcst06hour10['9'] + fcst06hour10['10'] + fcst06hour10['13'] + fcst06hour10['14']) / 8
fcst12hour10urban = (fcst12hour10['0'] + fcst12hour10['1'] + fcst12hour10['2'] + fcst12hour10['4'] + fcst12hour10['9'] + fcst12hour10['10'] + fcst12hour10['13'] + fcst12hour10['14']) / 8
fcst18hour10urban = (fcst18hour10['0'] + fcst18hour10['1'] + fcst18hour10['2'] + fcst18hour10['4'] + fcst18hour10['9'] + fcst18hour10['10'] + fcst18hour10['13'] + fcst18hour10['14']) / 8

fcst00hour11urban = (fcst00hour11['0'] + fcst00hour11['1'] + fcst00hour11['2'] + fcst00hour11['4'] + fcst00hour11['9'] + fcst00hour11['10'] + fcst00hour11['13'] + fcst00hour11['14']) / 8
fcst06hour11urban = (fcst06hour11['0'] + fcst06hour11['1'] + fcst06hour11['2'] + fcst06hour11['4'] + fcst06hour11['9'] + fcst06hour11['10'] + fcst06hour11['13'] + fcst06hour11['14']) / 8
fcst12hour11urban = (fcst12hour11['0'] + fcst12hour11['1'] + fcst12hour11['2'] + fcst12hour11['4'] + fcst12hour11['9'] + fcst12hour11['10'] + fcst12hour11['13'] + fcst12hour11['14']) / 8
fcst18hour11urban = (fcst18hour11['0'] + fcst18hour11['1'] + fcst18hour11['2'] + fcst18hour11['4'] + fcst18hour11['9'] + fcst18hour11['10'] + fcst18hour11['13'] + fcst18hour11['14']) / 8

fcst00hour12urban = (fcst00hour12['0'] + fcst00hour12['1'] + fcst00hour12['2'] + fcst00hour12['4'] + fcst00hour12['9'] + fcst00hour12['10'] + fcst00hour12['13'] + fcst00hour12['14']) / 8
fcst06hour12urban = (fcst06hour12['0'] + fcst06hour12['1'] + fcst06hour12['2'] + fcst06hour12['4'] + fcst06hour12['9'] + fcst06hour12['10'] + fcst06hour12['13'] + fcst06hour12['14']) / 8
fcst12hour12urban = (fcst12hour12['0'] + fcst12hour12['1'] + fcst12hour12['2'] + fcst12hour12['4'] + fcst12hour12['9'] + fcst12hour12['10'] + fcst12hour12['13'] + fcst12hour12['14']) / 8
fcst18hour12urban = (fcst18hour12['0'] + fcst18hour12['1'] + fcst18hour12['2'] + fcst18hour12['4'] + fcst18hour12['9'] + fcst18hour12['10'] + fcst18hour12['13'] + fcst18hour12['14']) / 8

fcst00hour13urban = (fcst00hour13['0'] + fcst00hour13['1'] + fcst00hour13['2'] + fcst00hour13['4'] + fcst00hour13['9'] + fcst00hour13['10'] + fcst00hour13['13'] + fcst00hour13['14']) / 8
fcst06hour13urban = (fcst06hour13['0'] + fcst06hour13['1'] + fcst06hour13['2'] + fcst06hour13['4'] + fcst06hour13['9'] + fcst06hour13['10'] + fcst06hour13['13'] + fcst06hour13['14']) / 8
fcst12hour13urban = (fcst12hour13['0'] + fcst12hour13['1'] + fcst12hour13['2'] + fcst12hour13['4'] + fcst12hour13['9'] + fcst12hour13['10'] + fcst12hour13['13'] + fcst12hour13['14']) / 8
fcst18hour13urban = (fcst18hour13['0'] + fcst18hour13['1'] + fcst18hour13['2'] + fcst18hour13['4'] + fcst18hour13['9'] + fcst18hour13['10'] + fcst18hour13['13'] + fcst18hour13['14']) / 8

fcst00hour14urban = (fcst00hour14['0'] + fcst00hour14['1'] + fcst00hour14['2'] + fcst00hour14['4'] + fcst00hour14['9'] + fcst00hour14['10'] + fcst00hour14['13'] + fcst00hour14['14']) / 8
fcst06hour14urban = (fcst06hour14['0'] + fcst06hour14['1'] + fcst06hour14['2'] + fcst06hour14['4'] + fcst06hour14['9'] + fcst06hour14['10'] + fcst06hour14['13'] + fcst06hour14['14']) / 8
fcst12hour14urban = (fcst12hour14['0'] + fcst12hour14['1'] + fcst12hour14['2'] + fcst12hour14['4'] + fcst12hour14['9'] + fcst12hour14['10'] + fcst12hour14['13'] + fcst12hour14['14']) / 8
fcst18hour14urban = (fcst18hour14['0'] + fcst18hour14['1'] + fcst18hour14['2'] + fcst18hour14['4'] + fcst18hour14['9'] + fcst18hour14['10'] + fcst18hour14['13'] + fcst18hour14['14']) / 8

fcst00hour15urban = (fcst00hour15['0'] + fcst00hour15['1'] + fcst00hour15['2'] + fcst00hour15['4'] + fcst00hour15['9'] + fcst00hour15['10'] + fcst00hour15['13'] + fcst00hour15['14']) / 8
fcst06hour15urban = (fcst06hour15['0'] + fcst06hour15['1'] + fcst06hour15['2'] + fcst06hour15['4'] + fcst06hour15['9'] + fcst06hour15['10'] + fcst06hour15['13'] + fcst06hour15['14']) / 8
fcst12hour15urban = (fcst12hour15['0'] + fcst12hour15['1'] + fcst12hour15['2'] + fcst12hour15['4'] + fcst12hour15['9'] + fcst12hour15['10'] + fcst12hour15['13'] + fcst12hour15['14']) / 8
fcst18hour15urban = (fcst18hour15['0'] + fcst18hour15['1'] + fcst18hour15['2'] + fcst18hour15['4'] + fcst18hour15['9'] + fcst18hour15['10'] + fcst18hour15['13'] + fcst18hour15['14']) / 8

fcst00hour16urban = (fcst00hour16['0'] + fcst00hour16['1'] + fcst00hour16['2'] + fcst00hour16['4'] + fcst00hour16['9'] + fcst00hour16['10'] + fcst00hour16['13'] + fcst00hour16['14']) / 8
fcst06hour16urban = (fcst06hour16['0'] + fcst06hour16['1'] + fcst06hour16['2'] + fcst06hour16['4'] + fcst06hour16['9'] + fcst06hour16['10'] + fcst06hour16['13'] + fcst06hour16['14']) / 8
fcst12hour16urban = (fcst12hour16['0'] + fcst12hour16['1'] + fcst12hour16['2'] + fcst12hour16['4'] + fcst12hour16['9'] + fcst12hour16['10'] + fcst12hour16['13'] + fcst12hour16['14']) / 8
fcst18hour16urban = (fcst18hour16['0'] + fcst18hour16['1'] + fcst18hour16['2'] + fcst18hour16['4'] + fcst18hour16['9'] + fcst18hour16['10'] + fcst18hour16['13'] + fcst18hour16['14']) / 8

fcst00hour17urban = (fcst00hour17['0'] + fcst00hour17['1'] + fcst00hour17['2'] + fcst00hour17['4'] + fcst00hour17['9'] + fcst00hour17['10'] + fcst00hour17['13'] + fcst00hour17['14']) / 8
fcst06hour17urban = (fcst06hour17['0'] + fcst06hour17['1'] + fcst06hour17['2'] + fcst06hour17['4'] + fcst06hour17['9'] + fcst06hour17['10'] + fcst06hour17['13'] + fcst06hour17['14']) / 8
fcst12hour17urban = (fcst12hour17['0'] + fcst12hour17['1'] + fcst12hour17['2'] + fcst12hour17['4'] + fcst12hour17['9'] + fcst12hour17['10'] + fcst12hour17['13'] + fcst12hour17['14']) / 8
fcst18hour17urban = (fcst18hour17['0'] + fcst18hour17['1'] + fcst18hour17['2'] + fcst18hour17['4'] + fcst18hour17['9'] + fcst18hour17['10'] + fcst18hour17['13'] + fcst18hour17['14']) / 8

fcst00hour18urban = (fcst00hour18['0'] + fcst00hour18['1'] + fcst00hour18['2'] + fcst00hour18['4'] + fcst00hour18['9'] + fcst00hour18['10'] + fcst00hour18['13'] + fcst00hour18['14']) / 8
fcst06hour18urban = (fcst06hour18['0'] + fcst06hour18['1'] + fcst06hour18['2'] + fcst06hour18['4'] + fcst06hour18['9'] + fcst06hour18['10'] + fcst06hour18['13'] + fcst06hour18['14']) / 8
fcst12hour18urban = (fcst12hour18['0'] + fcst12hour18['1'] + fcst12hour18['2'] + fcst12hour18['4'] + fcst12hour18['9'] + fcst12hour18['10'] + fcst12hour18['13'] + fcst12hour18['14']) / 8
fcst18hour18urban = (fcst18hour18['0'] + fcst18hour18['1'] + fcst18hour18['2'] + fcst18hour18['4'] + fcst18hour18['9'] + fcst18hour18['10'] + fcst18hour18['13'] + fcst18hour18['14']) / 8

fcst00hour19urban = (fcst00hour19['0'] + fcst00hour19['1'] + fcst00hour19['2'] + fcst00hour19['4'] + fcst00hour19['9'] + fcst00hour19['10'] + fcst00hour19['13'] + fcst00hour19['14']) / 8
fcst06hour19urban = (fcst06hour19['0'] + fcst06hour19['1'] + fcst06hour19['2'] + fcst06hour19['4'] + fcst06hour19['9'] + fcst06hour19['10'] + fcst06hour19['13'] + fcst06hour19['14']) / 8
fcst12hour19urban = (fcst12hour19['0'] + fcst12hour19['1'] + fcst12hour19['2'] + fcst12hour19['4'] + fcst12hour19['9'] + fcst12hour19['10'] + fcst12hour19['13'] + fcst12hour19['14']) / 8
fcst18hour19urban = (fcst18hour19['0'] + fcst18hour19['1'] + fcst18hour19['2'] + fcst18hour19['4'] + fcst18hour19['9'] + fcst18hour19['10'] + fcst18hour19['13'] + fcst18hour19['14']) / 8

fcst00hour20urban = (fcst00hour20['0'] + fcst00hour20['1'] + fcst00hour20['2'] + fcst00hour20['4'] + fcst00hour20['9'] + fcst00hour20['10'] + fcst00hour20['13'] + fcst00hour20['14']) / 8
fcst06hour20urban = (fcst06hour20['0'] + fcst06hour20['1'] + fcst06hour20['2'] + fcst06hour20['4'] + fcst06hour20['9'] + fcst06hour20['10'] + fcst06hour20['13'] + fcst06hour20['14']) / 8
fcst12hour20urban = (fcst12hour20['0'] + fcst12hour20['1'] + fcst12hour20['2'] + fcst12hour20['4'] + fcst12hour20['9'] + fcst12hour20['10'] + fcst12hour20['13'] + fcst12hour20['14']) / 8
fcst18hour20urban = (fcst18hour20['0'] + fcst18hour20['1'] + fcst18hour20['2'] + fcst18hour20['4'] + fcst18hour20['9'] + fcst18hour20['10'] + fcst18hour20['13'] + fcst18hour20['14']) / 8

fcst00hour21urban = (fcst00hour21['0'] + fcst00hour21['1'] + fcst00hour21['2'] + fcst00hour21['4'] + fcst00hour21['9'] + fcst00hour21['10'] + fcst00hour21['13'] + fcst00hour21['14']) / 8
fcst06hour21urban = (fcst06hour21['0'] + fcst06hour21['1'] + fcst06hour21['2'] + fcst06hour21['4'] + fcst06hour21['9'] + fcst06hour21['10'] + fcst06hour21['13'] + fcst06hour21['14']) / 8
fcst12hour21urban = (fcst12hour21['0'] + fcst12hour21['1'] + fcst12hour21['2'] + fcst12hour21['4'] + fcst12hour21['9'] + fcst12hour21['10'] + fcst12hour21['13'] + fcst12hour21['14']) / 8
fcst18hour21urban = (fcst18hour21['0'] + fcst18hour21['1'] + fcst18hour21['2'] + fcst18hour21['4'] + fcst18hour21['9'] + fcst18hour21['10'] + fcst18hour21['13'] + fcst18hour21['14']) / 8

fcst00hour22urban = (fcst00hour22['0'] + fcst00hour22['1'] + fcst00hour22['2'] + fcst00hour22['4'] + fcst00hour22['9'] + fcst00hour22['10'] + fcst00hour22['13'] + fcst00hour22['14']) / 8
fcst06hour22urban = (fcst06hour22['0'] + fcst06hour22['1'] + fcst06hour22['2'] + fcst06hour22['4'] + fcst06hour22['9'] + fcst06hour22['10'] + fcst06hour22['13'] + fcst06hour22['14']) / 8
fcst12hour22urban = (fcst12hour22['0'] + fcst12hour22['1'] + fcst12hour22['2'] + fcst12hour22['4'] + fcst12hour22['9'] + fcst12hour22['10'] + fcst12hour22['13'] + fcst12hour22['14']) / 8
fcst18hour22urban = (fcst18hour22['0'] + fcst18hour22['1'] + fcst18hour22['2'] + fcst18hour22['4'] + fcst18hour22['9'] + fcst18hour22['10'] + fcst18hour22['13'] + fcst18hour22['14']) / 8

fcst00hour23urban = (fcst00hour23['0'] + fcst00hour23['1'] + fcst00hour23['2'] + fcst00hour23['4'] + fcst00hour23['9'] + fcst00hour23['10'] + fcst00hour23['13'] + fcst00hour23['14']) / 8
fcst06hour23urban = (fcst06hour23['0'] + fcst06hour23['1'] + fcst06hour23['2'] + fcst06hour23['4'] + fcst06hour23['9'] + fcst06hour23['10'] + fcst06hour23['13'] + fcst06hour23['14']) / 8
fcst12hour23urban = (fcst12hour23['0'] + fcst12hour23['1'] + fcst12hour23['2'] + fcst12hour23['4'] + fcst12hour23['9'] + fcst12hour23['10'] + fcst12hour23['13'] + fcst12hour23['14']) / 8
fcst18hour23urban = (fcst18hour23['0'] + fcst18hour23['1'] + fcst18hour23['2'] + fcst18hour23['4'] + fcst18hour23['9'] + fcst18hour23['10'] + fcst18hour23['13'] + fcst18hour23['14']) / 8

# %%
fcst00hour00suburban = (fcst00hour00['15'] + fcst00hour00['6'] + fcst00hour00['9'] + fcst00hour00['11'] + fcst00hour00['12']) / 5
fcst06hour00suburban = (fcst06hour00['15'] + fcst06hour00['6'] + fcst06hour00['9'] + fcst06hour00['11'] + fcst06hour00['12']) / 5
fcst12hour00suburban = (fcst12hour00['15'] + fcst12hour00['6'] + fcst12hour00['9'] + fcst12hour00['11'] + fcst12hour00['12']) / 5
fcst18hour00suburban = (fcst18hour00['15'] + fcst18hour00['6'] + fcst18hour00['9'] + fcst18hour00['11'] + fcst18hour00['12']) / 5

fcst00hour01suburban = (fcst00hour01['15'] + fcst00hour01['6'] + fcst00hour01['9'] + fcst00hour01['11'] + fcst00hour01['12']) / 5
fcst06hour01suburban = (fcst06hour01['15'] + fcst06hour01['6'] + fcst06hour01['9'] + fcst06hour01['11'] + fcst06hour01['12']) / 5
fcst12hour01suburban = (fcst12hour01['15'] + fcst12hour01['6'] + fcst12hour01['9'] + fcst12hour01['11'] + fcst12hour01['12']) / 5
fcst18hour01suburban = (fcst18hour01['15'] + fcst18hour01['6'] + fcst18hour01['9'] + fcst18hour01['11'] + fcst18hour01['12']) / 5

fcst00hour02suburban = (fcst00hour02['15'] + fcst00hour02['6'] + fcst00hour02['9'] + fcst00hour02['11'] + fcst00hour02['12']) / 5
fcst06hour02suburban = (fcst06hour02['15'] + fcst06hour02['6'] + fcst06hour02['9'] + fcst06hour02['11'] + fcst06hour02['12']) / 5
fcst12hour02suburban = (fcst12hour02['15'] + fcst12hour02['6'] + fcst12hour02['9'] + fcst12hour02['11'] + fcst12hour02['12']) / 5
fcst18hour02suburban = (fcst18hour02['15'] + fcst18hour02['6'] + fcst18hour02['9'] + fcst18hour02['11'] + fcst18hour02['12']) / 5

fcst00hour03suburban = (fcst00hour03['15'] + fcst00hour03['6'] + fcst00hour03['9'] + fcst00hour03['11'] + fcst00hour03['12']) / 5
fcst06hour03suburban = (fcst06hour03['15'] + fcst06hour03['6'] + fcst06hour03['9'] + fcst06hour03['11'] + fcst06hour03['12']) / 5
fcst12hour03suburban = (fcst12hour03['15'] + fcst12hour03['6'] + fcst12hour03['9'] + fcst12hour03['11'] + fcst12hour03['12']) / 5
fcst18hour03suburban = (fcst18hour03['15'] + fcst18hour03['6'] + fcst18hour03['9'] + fcst18hour03['11'] + fcst18hour03['12']) / 5

fcst00hour04suburban = (fcst00hour04['15'] + fcst00hour04['6'] + fcst00hour04['9'] + fcst00hour04['11'] + fcst00hour04['12']) / 5
fcst06hour04suburban = (fcst06hour04['15'] + fcst06hour04['6'] + fcst06hour04['9'] + fcst06hour04['11'] + fcst06hour04['12']) / 5
fcst12hour04suburban = (fcst12hour04['15'] + fcst12hour04['6'] + fcst12hour04['9'] + fcst12hour04['11'] + fcst12hour04['12']) / 5
fcst18hour04suburban = (fcst18hour04['15'] + fcst18hour04['6'] + fcst18hour04['9'] + fcst18hour04['11'] + fcst18hour04['12']) / 5

fcst00hour05suburban = (fcst00hour05['15'] + fcst00hour05['6'] + fcst00hour05['9'] + fcst00hour05['11'] + fcst00hour05['12']) / 5
fcst06hour05suburban = (fcst06hour05['15'] + fcst06hour05['6'] + fcst06hour05['9'] + fcst06hour05['11'] + fcst06hour05['12']) / 5
fcst12hour05suburban = (fcst12hour05['15'] + fcst12hour05['6'] + fcst12hour05['9'] + fcst12hour05['11'] + fcst12hour05['12']) / 5
fcst18hour05suburban = (fcst18hour05['15'] + fcst18hour05['6'] + fcst18hour05['9'] + fcst18hour05['11'] + fcst18hour05['12']) / 5

fcst00hour06suburban = (fcst00hour06['15'] + fcst00hour06['6'] + fcst00hour06['9'] + fcst00hour06['11'] + fcst00hour06['12']) / 5
fcst06hour06suburban = (fcst06hour06['15'] + fcst06hour06['6'] + fcst06hour06['9'] + fcst06hour06['11'] + fcst06hour06['12']) / 5
fcst12hour06suburban = (fcst12hour06['15'] + fcst12hour06['6'] + fcst12hour06['9'] + fcst12hour06['11'] + fcst12hour06['12']) / 5
fcst18hour06suburban = (fcst18hour06['15'] + fcst18hour06['6'] + fcst18hour06['9'] + fcst18hour06['11'] + fcst18hour06['12']) / 5

fcst00hour07suburban = (fcst00hour07['15'] + fcst00hour07['6'] + fcst00hour07['9'] + fcst00hour07['11'] + fcst00hour07['12']) / 5
fcst06hour07suburban = (fcst06hour07['15'] + fcst06hour07['6'] + fcst06hour07['9'] + fcst06hour07['11'] + fcst06hour07['12']) / 5
fcst12hour07suburban = (fcst12hour07['15'] + fcst12hour07['6'] + fcst12hour07['9'] + fcst12hour07['11'] + fcst12hour07['12']) / 5
fcst18hour07suburban = (fcst18hour07['15'] + fcst18hour07['6'] + fcst18hour07['9'] + fcst18hour07['11'] + fcst18hour07['12']) / 5

fcst00hour08suburban = (fcst00hour08['15'] + fcst00hour08['6'] + fcst00hour08['9'] + fcst00hour08['11'] + fcst00hour08['12']) / 5
fcst06hour08suburban = (fcst06hour08['15'] + fcst06hour08['6'] + fcst06hour08['9'] + fcst06hour08['11'] + fcst06hour08['12']) / 5
fcst12hour08suburban = (fcst12hour08['15'] + fcst12hour08['6'] + fcst12hour08['9'] + fcst12hour08['11'] + fcst12hour08['12']) / 5
fcst18hour08suburban = (fcst18hour08['15'] + fcst18hour08['6'] + fcst18hour08['9'] + fcst18hour08['11'] + fcst18hour08['12']) / 5

fcst00hour09suburban = (fcst00hour09['15'] + fcst00hour09['6'] + fcst00hour09['9'] + fcst00hour09['11'] + fcst00hour09['12']) / 5
fcst06hour09suburban = (fcst06hour09['15'] + fcst06hour09['6'] + fcst06hour09['9'] + fcst06hour09['11'] + fcst06hour09['12']) / 5
fcst12hour09suburban = (fcst12hour09['15'] + fcst12hour09['6'] + fcst12hour09['9'] + fcst12hour09['11'] + fcst12hour09['12']) / 5
fcst18hour09suburban = (fcst18hour09['15'] + fcst18hour09['6'] + fcst18hour09['9'] + fcst18hour09['11'] + fcst18hour09['12']) / 5

fcst00hour10suburban = (fcst00hour10['15'] + fcst00hour10['6'] + fcst00hour10['9'] + fcst00hour10['11'] + fcst00hour10['12']) / 5
fcst06hour10suburban = (fcst06hour10['15'] + fcst06hour10['6'] + fcst06hour10['9'] + fcst06hour10['11'] + fcst06hour10['12']) / 5
fcst12hour10suburban = (fcst12hour10['15'] + fcst12hour10['6'] + fcst12hour10['9'] + fcst12hour10['11'] + fcst12hour10['12']) / 5
fcst18hour10suburban = (fcst18hour10['15'] + fcst18hour10['6'] + fcst18hour10['9'] + fcst18hour10['11'] + fcst18hour10['12']) / 5

fcst00hour11suburban = (fcst00hour11['15'] + fcst00hour11['6'] + fcst00hour11['9'] + fcst00hour11['11'] + fcst00hour11['12']) / 5
fcst06hour11suburban = (fcst06hour11['15'] + fcst06hour11['6'] + fcst06hour11['9'] + fcst06hour11['11'] + fcst06hour11['12']) / 5
fcst12hour11suburban = (fcst12hour11['15'] + fcst12hour11['6'] + fcst12hour11['9'] + fcst12hour11['11'] + fcst12hour11['12']) / 5
fcst18hour11suburban = (fcst18hour11['15'] + fcst18hour11['6'] + fcst18hour11['9'] + fcst18hour11['11'] + fcst18hour11['12']) / 5

fcst00hour12suburban = (fcst00hour12['15'] + fcst00hour12['6'] + fcst00hour12['9'] + fcst00hour12['11'] + fcst00hour12['12']) / 5
fcst06hour12suburban = (fcst06hour12['15'] + fcst06hour12['6'] + fcst06hour12['9'] + fcst06hour12['11'] + fcst06hour12['12']) / 5
fcst12hour12suburban = (fcst12hour12['15'] + fcst12hour12['6'] + fcst12hour12['9'] + fcst12hour12['11'] + fcst12hour12['12']) / 5
fcst18hour12suburban = (fcst18hour12['15'] + fcst18hour12['6'] + fcst18hour12['9'] + fcst18hour12['11'] + fcst18hour12['12']) / 5

fcst00hour13suburban = (fcst00hour13['15'] + fcst00hour13['6'] + fcst00hour13['9'] + fcst00hour13['11'] + fcst00hour13['12']) / 5
fcst06hour13suburban = (fcst06hour13['15'] + fcst06hour13['6'] + fcst06hour13['9'] + fcst06hour13['11'] + fcst06hour13['12']) / 5
fcst12hour13suburban = (fcst12hour13['15'] + fcst12hour13['6'] + fcst12hour13['9'] + fcst12hour13['11'] + fcst12hour13['12']) / 5
fcst18hour13suburban = (fcst18hour13['15'] + fcst18hour13['6'] + fcst18hour13['9'] + fcst18hour13['11'] + fcst18hour13['12']) / 5

fcst00hour14suburban = (fcst00hour14['15'] + fcst00hour14['6'] + fcst00hour14['9'] + fcst00hour14['11'] + fcst00hour14['12']) / 5
fcst06hour14suburban = (fcst06hour14['15'] + fcst06hour14['6'] + fcst06hour14['9'] + fcst06hour14['11'] + fcst06hour14['12']) / 5
fcst12hour14suburban = (fcst12hour14['15'] + fcst12hour14['6'] + fcst12hour14['9'] + fcst12hour14['11'] + fcst12hour14['12']) / 5
fcst18hour14suburban = (fcst18hour14['15'] + fcst18hour14['6'] + fcst18hour14['9'] + fcst18hour14['11'] + fcst18hour14['12']) / 5

fcst00hour15suburban = (fcst00hour15['15'] + fcst00hour15['6'] + fcst00hour15['9'] + fcst00hour15['11'] + fcst00hour15['12']) / 5
fcst06hour15suburban = (fcst06hour15['15'] + fcst06hour15['6'] + fcst06hour15['9'] + fcst06hour15['11'] + fcst06hour15['12']) / 5
fcst12hour15suburban = (fcst12hour15['15'] + fcst12hour15['6'] + fcst12hour15['9'] + fcst12hour15['11'] + fcst12hour15['12']) / 5
fcst18hour15suburban = (fcst18hour15['15'] + fcst18hour15['6'] + fcst18hour15['9'] + fcst18hour15['11'] + fcst18hour15['12']) / 5

fcst00hour16suburban = (fcst00hour16['15'] + fcst00hour16['6'] + fcst00hour16['9'] + fcst00hour16['11'] + fcst00hour16['12']) / 5
fcst06hour16suburban = (fcst06hour16['15'] + fcst06hour16['6'] + fcst06hour16['9'] + fcst06hour16['11'] + fcst06hour16['12']) / 5
fcst12hour16suburban = (fcst12hour16['15'] + fcst12hour16['6'] + fcst12hour16['9'] + fcst12hour16['11'] + fcst12hour16['12']) / 5
fcst18hour16suburban = (fcst18hour16['15'] + fcst18hour16['6'] + fcst18hour16['9'] + fcst18hour16['11'] + fcst18hour16['12']) / 5

fcst00hour17suburban = (fcst00hour17['15'] + fcst00hour17['6'] + fcst00hour17['9'] + fcst00hour17['11'] + fcst00hour17['12']) / 5
fcst06hour17suburban = (fcst06hour17['15'] + fcst06hour17['6'] + fcst06hour17['9'] + fcst06hour17['11'] + fcst06hour17['12']) / 5
fcst12hour17suburban = (fcst12hour17['15'] + fcst12hour17['6'] + fcst12hour17['9'] + fcst12hour17['11'] + fcst12hour17['12']) / 5
fcst18hour17suburban = (fcst18hour17['15'] + fcst18hour17['6'] + fcst18hour17['9'] + fcst18hour17['11'] + fcst18hour17['12']) / 5

fcst00hour18suburban = (fcst00hour18['15'] + fcst00hour18['6'] + fcst00hour18['9'] + fcst00hour18['11'] + fcst00hour18['12']) / 5
fcst06hour18suburban = (fcst06hour18['15'] + fcst06hour18['6'] + fcst06hour18['9'] + fcst06hour18['11'] + fcst06hour18['12']) / 5
fcst12hour18suburban = (fcst12hour18['15'] + fcst12hour18['6'] + fcst12hour18['9'] + fcst12hour18['11'] + fcst12hour18['12']) / 5
fcst18hour18suburban = (fcst18hour18['15'] + fcst18hour18['6'] + fcst18hour18['9'] + fcst18hour18['11'] + fcst18hour18['12']) / 5

fcst00hour19suburban = (fcst00hour19['15'] + fcst00hour19['6'] + fcst00hour19['9'] + fcst00hour19['11'] + fcst00hour19['12']) / 5
fcst06hour19suburban = (fcst06hour19['15'] + fcst06hour19['6'] + fcst06hour19['9'] + fcst06hour19['11'] + fcst06hour19['12']) / 5
fcst12hour19suburban = (fcst12hour19['15'] + fcst12hour19['6'] + fcst12hour19['9'] + fcst12hour19['11'] + fcst12hour19['12']) / 5
fcst18hour19suburban = (fcst18hour19['15'] + fcst18hour19['6'] + fcst18hour19['9'] + fcst18hour19['11'] + fcst18hour19['12']) / 5

fcst00hour20suburban = (fcst00hour20['15'] + fcst00hour20['6'] + fcst00hour20['9'] + fcst00hour20['11'] + fcst00hour20['12']) / 5
fcst06hour20suburban = (fcst06hour20['15'] + fcst06hour20['6'] + fcst06hour20['9'] + fcst06hour20['11'] + fcst06hour20['12']) / 5
fcst12hour20suburban = (fcst12hour20['15'] + fcst12hour20['6'] + fcst12hour20['9'] + fcst12hour20['11'] + fcst12hour20['12']) / 5
fcst18hour20suburban = (fcst18hour20['15'] + fcst18hour20['6'] + fcst18hour20['9'] + fcst18hour20['11'] + fcst18hour20['12']) / 5

fcst00hour21suburban = (fcst00hour21['15'] + fcst00hour21['6'] + fcst00hour21['9'] + fcst00hour21['11'] + fcst00hour21['12']) / 5
fcst06hour21suburban = (fcst06hour21['15'] + fcst06hour21['6'] + fcst06hour21['9'] + fcst06hour21['11'] + fcst06hour21['12']) / 5
fcst12hour21suburban = (fcst12hour21['15'] + fcst12hour21['6'] + fcst12hour21['9'] + fcst12hour21['11'] + fcst12hour21['12']) / 5
fcst18hour21suburban = (fcst18hour21['15'] + fcst18hour21['6'] + fcst18hour21['9'] + fcst18hour21['11'] + fcst18hour21['12']) / 5

fcst00hour22suburban = (fcst00hour22['15'] + fcst00hour22['6'] + fcst00hour22['9'] + fcst00hour22['11'] + fcst00hour22['12']) / 5
fcst06hour22suburban = (fcst06hour22['15'] + fcst06hour22['6'] + fcst06hour22['9'] + fcst06hour22['11'] + fcst06hour22['12']) / 5
fcst12hour22suburban = (fcst12hour22['15'] + fcst12hour22['6'] + fcst12hour22['9'] + fcst12hour22['11'] + fcst12hour22['12']) / 5
fcst18hour22suburban = (fcst18hour22['15'] + fcst18hour22['6'] + fcst18hour22['9'] + fcst18hour22['11'] + fcst18hour22['12']) / 5

fcst00hour23suburban = (fcst00hour23['15'] + fcst00hour23['6'] + fcst00hour23['9'] + fcst00hour23['11'] + fcst00hour23['12']) / 5
fcst06hour23suburban = (fcst06hour23['15'] + fcst06hour23['6'] + fcst06hour23['9'] + fcst06hour23['11'] + fcst06hour23['12']) / 5
fcst12hour23suburban = (fcst12hour23['15'] + fcst12hour23['6'] + fcst12hour23['9'] + fcst12hour23['11'] + fcst12hour23['12']) / 5
fcst18hour23suburban = (fcst18hour23['15'] + fcst18hour23['6'] + fcst18hour23['9'] + fcst18hour23['11'] + fcst18hour23['12']) / 5

# %%
fcst00hour00rural = (fcst00hour00['4'] + fcst00hour00['5'] + fcst00hour00['8']) / 3
fcst06hour00rural = (fcst06hour00['4'] + fcst06hour00['5'] + fcst06hour00['8']) / 3
fcst12hour00rural = (fcst12hour00['4'] + fcst12hour00['5'] + fcst12hour00['8']) / 3
fcst18hour00rural = (fcst18hour00['4'] + fcst18hour00['5'] + fcst18hour00['8']) / 3

fcst00hour01rural = (fcst00hour01['4'] + fcst00hour01['5'] + fcst00hour01['8']) / 3
fcst06hour01rural = (fcst06hour01['4'] + fcst06hour01['5'] + fcst06hour01['8']) / 3
fcst12hour01rural = (fcst12hour01['4'] + fcst12hour01['5'] + fcst12hour01['8']) / 3
fcst18hour01rural = (fcst18hour01['4'] + fcst18hour01['5'] + fcst18hour01['8']) / 3

fcst00hour02rural = (fcst00hour02['4'] + fcst00hour02['5'] + fcst00hour02['8']) / 3
fcst06hour02rural = (fcst06hour02['4'] + fcst06hour02['5'] + fcst06hour02['8']) / 3
fcst12hour02rural = (fcst12hour02['4'] + fcst12hour02['5'] + fcst12hour02['8']) / 3
fcst18hour02rural = (fcst18hour02['4'] + fcst18hour02['5'] + fcst18hour02['8']) / 3

fcst00hour03rural = (fcst00hour03['4'] + fcst00hour03['5'] + fcst00hour03['8']) / 3
fcst06hour03rural = (fcst06hour03['4'] + fcst06hour03['5'] + fcst06hour03['8']) / 3
fcst12hour03rural = (fcst12hour03['4'] + fcst12hour03['5'] + fcst12hour03['8']) / 3
fcst18hour03rural = (fcst18hour03['4'] + fcst18hour03['5'] + fcst18hour03['8']) / 3

fcst00hour04rural = (fcst00hour04['4'] + fcst00hour04['5'] + fcst00hour04['8']) / 3
fcst06hour04rural = (fcst06hour04['4'] + fcst06hour04['5'] + fcst06hour04['8']) / 3
fcst12hour04rural = (fcst12hour04['4'] + fcst12hour04['5'] + fcst12hour04['8']) / 3
fcst18hour04rural = (fcst18hour04['4'] + fcst18hour04['5'] + fcst18hour04['8']) / 3

fcst00hour05rural = (fcst00hour05['4'] + fcst00hour05['5'] + fcst00hour05['8']) / 3
fcst06hour05rural = (fcst06hour05['4'] + fcst06hour05['5'] + fcst06hour05['8']) / 3
fcst12hour05rural = (fcst12hour05['4'] + fcst12hour05['5'] + fcst12hour05['8']) / 3
fcst18hour05rural = (fcst18hour05['4'] + fcst18hour05['5'] + fcst18hour05['8']) / 3

fcst00hour06rural = (fcst00hour06['4'] + fcst00hour06['5'] + fcst00hour06['8']) / 3
fcst06hour06rural = (fcst06hour06['4'] + fcst06hour06['5'] + fcst06hour06['8']) / 3
fcst12hour06rural = (fcst12hour06['4'] + fcst12hour06['5'] + fcst12hour06['8']) / 3
fcst18hour06rural = (fcst18hour06['4'] + fcst18hour06['5'] + fcst18hour06['8']) / 3

fcst00hour07rural = (fcst00hour07['4'] + fcst00hour07['5'] + fcst00hour07['8']) / 3
fcst06hour07rural = (fcst06hour07['4'] + fcst06hour07['5'] + fcst06hour07['8']) / 3
fcst12hour07rural = (fcst12hour07['4'] + fcst12hour07['5'] + fcst12hour07['8']) / 3
fcst18hour07rural = (fcst18hour07['4'] + fcst18hour07['5'] + fcst18hour07['8']) / 3

fcst00hour08rural = (fcst00hour08['4'] + fcst00hour08['5'] + fcst00hour08['8']) / 3
fcst06hour08rural = (fcst06hour08['4'] + fcst06hour08['5'] + fcst06hour08['8']) / 3
fcst12hour08rural = (fcst12hour08['4'] + fcst12hour08['5'] + fcst12hour08['8']) / 3
fcst18hour08rural = (fcst18hour08['4'] + fcst18hour08['5'] + fcst18hour08['8']) / 3

fcst00hour09rural = (fcst00hour09['4'] + fcst00hour09['5'] + fcst00hour09['8']) / 3
fcst06hour09rural = (fcst06hour09['4'] + fcst06hour09['5'] + fcst06hour09['8']) / 3
fcst12hour09rural = (fcst12hour09['4'] + fcst12hour09['5'] + fcst12hour09['8']) / 3
fcst18hour09rural = (fcst18hour09['4'] + fcst18hour09['5'] + fcst18hour09['8']) / 3

fcst00hour10rural = (fcst00hour10['4'] + fcst00hour10['5'] + fcst00hour10['8']) / 3
fcst06hour10rural = (fcst06hour10['4'] + fcst06hour10['5'] + fcst06hour10['8']) / 3
fcst12hour10rural = (fcst12hour10['4'] + fcst12hour10['5'] + fcst12hour10['8']) / 3
fcst18hour10rural = (fcst18hour10['4'] + fcst18hour10['5'] + fcst18hour10['8']) / 3

fcst00hour11rural = (fcst00hour11['4'] + fcst00hour11['5'] + fcst00hour11['8']) / 3
fcst06hour11rural = (fcst06hour11['4'] + fcst06hour11['5'] + fcst06hour11['8']) / 3
fcst12hour11rural = (fcst12hour11['4'] + fcst12hour11['5'] + fcst12hour11['8']) / 3
fcst18hour11rural = (fcst18hour11['4'] + fcst18hour11['5'] + fcst18hour11['8']) / 3

fcst00hour12rural = (fcst00hour12['4'] + fcst00hour12['5'] + fcst00hour12['8']) / 3
fcst06hour12rural = (fcst06hour12['4'] + fcst06hour12['5'] + fcst06hour12['8']) / 3
fcst12hour12rural = (fcst12hour12['4'] + fcst12hour12['5'] + fcst12hour12['8']) / 3
fcst18hour12rural = (fcst18hour12['4'] + fcst18hour12['5'] + fcst18hour12['8']) / 3

fcst00hour13rural = (fcst00hour13['4'] + fcst00hour13['5'] + fcst00hour13['8']) / 3
fcst06hour13rural = (fcst06hour13['4'] + fcst06hour13['5'] + fcst06hour13['8']) / 3
fcst12hour13rural = (fcst12hour13['4'] + fcst12hour13['5'] + fcst12hour13['8']) / 3
fcst18hour13rural = (fcst18hour13['4'] + fcst18hour13['5'] + fcst18hour13['8']) / 3

fcst00hour14rural = (fcst00hour14['4'] + fcst00hour14['5'] + fcst00hour14['8']) / 3
fcst06hour14rural = (fcst06hour14['4'] + fcst06hour14['5'] + fcst06hour14['8']) / 3
fcst12hour14rural = (fcst12hour14['4'] + fcst12hour14['5'] + fcst12hour14['8']) / 3
fcst18hour14rural = (fcst18hour14['4'] + fcst18hour14['5'] + fcst18hour14['8']) / 3

fcst00hour15rural = (fcst00hour15['4'] + fcst00hour15['5'] + fcst00hour15['8']) / 3
fcst06hour15rural = (fcst06hour15['4'] + fcst06hour15['5'] + fcst06hour15['8']) / 3
fcst12hour15rural = (fcst12hour15['4'] + fcst12hour15['5'] + fcst12hour15['8']) / 3
fcst18hour15rural = (fcst18hour15['4'] + fcst18hour15['5'] + fcst18hour15['8']) / 3

fcst00hour16rural = (fcst00hour16['4'] + fcst00hour16['5'] + fcst00hour16['8']) / 3
fcst06hour16rural = (fcst06hour16['4'] + fcst06hour16['5'] + fcst06hour16['8']) / 3
fcst12hour16rural = (fcst12hour16['4'] + fcst12hour16['5'] + fcst12hour16['8']) / 3
fcst18hour16rural = (fcst18hour16['4'] + fcst18hour16['5'] + fcst18hour16['8']) / 3

fcst00hour17rural = (fcst00hour17['4'] + fcst00hour17['5'] + fcst00hour17['8']) / 3
fcst06hour17rural = (fcst06hour17['4'] + fcst06hour17['5'] + fcst06hour17['8']) / 3
fcst12hour17rural = (fcst12hour17['4'] + fcst12hour17['5'] + fcst12hour17['8']) / 3
fcst18hour17rural = (fcst18hour17['4'] + fcst18hour17['5'] + fcst18hour17['8']) / 3

fcst00hour18rural = (fcst00hour18['4'] + fcst00hour18['5'] + fcst00hour18['8']) / 3
fcst06hour18rural = (fcst06hour18['4'] + fcst06hour18['5'] + fcst06hour18['8']) / 3
fcst12hour18rural = (fcst12hour18['4'] + fcst12hour18['5'] + fcst12hour18['8']) / 3
fcst18hour18rural = (fcst18hour18['4'] + fcst18hour18['5'] + fcst18hour18['8']) / 3

fcst00hour19rural = (fcst00hour19['4'] + fcst00hour19['5'] + fcst00hour19['8']) / 3
fcst06hour19rural = (fcst06hour19['4'] + fcst06hour19['5'] + fcst06hour19['8']) / 3
fcst12hour19rural = (fcst12hour19['4'] + fcst12hour19['5'] + fcst12hour19['8']) / 3
fcst18hour19rural = (fcst18hour19['4'] + fcst18hour19['5'] + fcst18hour19['8']) / 3

fcst00hour20rural = (fcst00hour20['4'] + fcst00hour20['5'] + fcst00hour20['8']) / 3
fcst06hour20rural = (fcst06hour20['4'] + fcst06hour20['5'] + fcst06hour20['8']) / 3
fcst12hour20rural = (fcst12hour20['4'] + fcst12hour20['5'] + fcst12hour20['8']) / 3
fcst18hour20rural = (fcst18hour20['4'] + fcst18hour20['5'] + fcst18hour20['8']) / 3

fcst00hour21rural = (fcst00hour21['4'] + fcst00hour21['5'] + fcst00hour21['8']) / 3
fcst06hour21rural = (fcst06hour21['4'] + fcst06hour21['5'] + fcst06hour21['8']) / 3
fcst12hour21rural = (fcst12hour21['4'] + fcst12hour21['5'] + fcst12hour21['8']) / 3
fcst18hour21rural = (fcst18hour21['4'] + fcst18hour21['5'] + fcst18hour21['8']) / 3

fcst00hour22rural = (fcst00hour22['4'] + fcst00hour22['5'] + fcst00hour22['8']) / 3
fcst06hour22rural = (fcst06hour22['4'] + fcst06hour22['5'] + fcst06hour22['8']) / 3
fcst12hour22rural = (fcst12hour22['4'] + fcst12hour22['5'] + fcst12hour22['8']) / 3
fcst18hour22rural = (fcst18hour22['4'] + fcst18hour22['5'] + fcst18hour22['8']) / 3

fcst00hour23rural = (fcst00hour23['4'] + fcst00hour23['5'] + fcst00hour23['8']) / 3
fcst06hour23rural = (fcst06hour23['4'] + fcst06hour23['5'] + fcst06hour23['8']) / 3
fcst12hour23rural = (fcst12hour23['4'] + fcst12hour23['5'] + fcst12hour23['8']) / 3
fcst18hour23rural = (fcst18hour23['4'] + fcst18hour23['5'] + fcst18hour23['8']) / 3

# %%
#DO NOT RUN MORE THAN ONCE IN SCRIPT  TEMPERATURE
df=pd.read_csv(r"C:\Users\sierra\Downloads\Mesonet_Hill.csv")
clarksville=[]
baltimore=[]
for ii in range(0,7222):
    if df['station_name'][ii] == 'Clarksville':
        clarksville.append(ii)
    if df['station_name'][ii] == 'Baltimore':
        baltimore.append(ii)
clarksvilleTMP=df['RelativeHumidity_2m_Avg'][0:clarksville[-1]-4]
baltimoreTMP=df['RelativeHumidity_2m_Avg'][baltimore[0]:baltimore[-1]-4]

timeindex = pd.date_range(start='2024-06-01-12:00:00',end='2024-08-31-23', freq='H')
clarksvilleTMP=clarksvilleTMP[8:]
baltimoreTMP=baltimoreTMP[8:]
clarksvilleTMP.index=timeindex
baltimoreTMP.index=timeindex

dayClarkTMP=clarksvilleTMP.between_time('10:00:00','00:00:00')
nightClarkTMP=clarksvilleTMP.between_time('1:00:00','9:00:00')
dayBaltTMP=baltimoreTMP.between_time('10:00:00','00:00:00')
nightBaltTMP=baltimoreTMP.between_time('1:00:00','9:00:00')

# %%
#Maryland Roadway Data Temperature US 1
df=pd.read_csv(r"C:\Users\sierra\Downloads\I-70 at MD 32_Export_20250206183402.csv")
df['time'] = pd.to_datetime(df['time'])
df['hour'] = df['time'].dt.hour

zeros=[]
ones=[]
twos=[]
threes=[]
fours=[]
fives=[]
sixes=[]
sevens=[]
eights=[]
nines=[]
tens=[]
elevens=[]
twelves=[]
thirteens=[]
fourteens=[]
fifteens=[]
sixteens=[]
seventeens=[]
eighteens=[]
nineteens=[]
twenty=[]
twentyone=[]
twentytwo=[]
twentythree=[]
for ii in range(0,26074):
    if df['hour'][ii] == 0:
        zeros.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 1:
        ones.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 2:
        twos.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 3:
        threes.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 4:
        fours.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 5:
        fives.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 6:
        sixes.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 7:
        sevens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 8:
        eights.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 9:
        nines.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 10:
        tens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 11:
        elevens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 12:
        twelves.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 13:
        thirteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 14:
        fourteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 15:
        fifteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 16:
        sixteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 17:
        seventeens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 18:
        eighteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 19:
        nineteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 20:
        twenty.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 21:
        twentyone.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 22:
        twentytwo.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 23:
        twentythree.append(df['Humidity [%]'][ii])
        
n = 12
zeros=[avg for avg in [sum(zeros[i:i+n])//n for i in range(0,len(zeros),n)] for j in range(n)]
zerosI70=zeros[0::12]

ones=[avg for avg in [sum(ones[i:i+n])//n for i in range(0,len(ones),n)] for j in range(n)]
onesI70=ones[0::12]       

twos=[avg for avg in [sum(twos[i:i+n])//n for i in range(0,len(twos),n)] for j in range(n)]
twosI70=twos[0::12]

threes=[avg for avg in [sum(threes[i:i+n])//n for i in range(0,len(threes),n)] for j in range(n)]
threesI70=threes[0::12] 

fours=[avg for avg in [sum(fours[i:i+n])//n for i in range(0,len(fours),n)] for j in range(n)]
foursI70=fours[0::12]

fives=[avg for avg in [sum(fives[i:i+n])//n for i in range(0,len(fives),n)] for j in range(n)]
fivesI70=fives[0::12]       

sixes=[avg for avg in [sum(sixes[i:i+n])//n for i in range(0,len(sixes),n)] for j in range(n)]
sixesI70=sixes[0::12]

sevens=[avg for avg in [sum(sevens[i:i+n])//n for i in range(0,len(sevens),n)] for j in range(n)]
sevensI70=sevens[0::12]

eights=[avg for avg in [sum(eights[i:i+n])//n for i in range(0,len(eights),n)] for j in range(n)]
eightsI70=eights[0::12]

nines=[avg for avg in [sum(nines[i:i+n])//n for i in range(0,len(nines),n)] for j in range(n)]
ninesI70=ones[0::12]       

tens=[avg for avg in [sum(tens[i:i+n])//n for i in range(0,len(tens),n)] for j in range(n)]
tensI70=tens[0::12]

elevens=[avg for avg in [sum(elevens[i:i+n])//n for i in range(0,len(elevens),n)] for j in range(n)]
elevensI70=elevens[0::12] 

twelves=[avg for avg in [sum(twelves[i:i+n])//n for i in range(0,len(twelves),n)] for j in range(n)]
twelvesI70=twelves[0::12]

thirteens=[avg for avg in [sum(thirteens[i:i+n])//n for i in range(0,len(thirteens),n)] for j in range(n)]
thirteensI70=thirteens[0::12]       

fourteens=[avg for avg in [sum(fourteens[i:i+n])//n for i in range(0,len(fourteens),n)] for j in range(n)]
fourteensI70=fourteens[0::12]

fifteens=[avg for avg in [sum(fifteens[i:i+n])//n for i in range(0,len(fifteens),n)] for j in range(n)]
fifteensI70=fifteens[0::12]

sixteens=[avg for avg in [sum(sixteens[i:i+n])//n for i in range(0,len(sixteens),n)] for j in range(n)]
sixteensI70=sixteens[0::12]

seventeens=[avg for avg in [sum(seventeens[i:i+n])//n for i in range(0,len(seventeens),n)] for j in range(n)]
seventeensI70=seventeens[0::12]

eighteens=[avg for avg in [sum(eighteens[i:i+n])//n for i in range(0,len(eighteens),n)] for j in range(n)]
eighteensI70=eights[0::12]

nineteens=[avg for avg in [sum(nineteens[i:i+n])//n for i in range(0,len(nineteens),n)] for j in range(n)]
nineteensI70=ones[0::12]       

twenty=[avg for avg in [sum(twenty[i:i+n])//n for i in range(0,len(twenty),n)] for j in range(n)]
twentyI70=twenty[0::12]

twentyone=[avg for avg in [sum(twentyone[i:i+n])//n for i in range(0,len(twentyone),n)] for j in range(n)]
twentyoneI70=twentyone[0::12] 

twentytwo=[avg for avg in [sum(twentytwo[i:i+n])//n for i in range(0,len(twentytwo),n)] for j in range(n)]
twentytwoI70=twentytwo[0::12]

twentythree=[avg for avg in [sum(twentythree[i:i+n])//n for i in range(0,len(twentythree),n)] for j in range(n)]
twentythreeI70=twentythree[0::12]

# %%
#Maryland Roadway Data Temperature US1
df=pd.read_csv(r"C:\Users\sierra\Downloads\US1atBalHarfCoLine_Export_20250206162439.csv")
df['time'] = pd.to_datetime(df['time'])
df['hour'] = df['time'].dt.hour

zeros=[]
ones=[]
twos=[]
threes=[]
fours=[]
fives=[]
sixes=[]
sevens=[]
eights=[]
nines=[]
tens=[]
elevens=[]
twelves=[]
thirteens=[]
fourteens=[]
fifteens=[]
sixteens=[]
seventeens=[]
eighteens=[]
nineteens=[]
twenty=[]
twentyone=[]
twentytwo=[]
twentythree=[]
for ii in range(0,26123):
    if df['hour'][ii] == 0:
        zeros.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 1:
        ones.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 2:
        twos.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 3:
        threes.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 4:
        fours.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 5:
        fives.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 6:
        sixes.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 7:
        sevens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 8:
        eights.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 9:
        nines.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 10:
        tens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 11:
        elevens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 12:
        twelves.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 13:
        thirteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 14:
        fourteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 15:
        fifteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 16:
        sixteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 17:
        seventeens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 18:
        eighteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 19:
        nineteens.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 20:
        twenty.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 21:
        twentyone.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 22:
        twentytwo.append(df['Humidity [%]'][ii])
    if df['hour'][ii] == 23:
        twentythree.append(df['Humidity [%]'][ii])
        
n = 12

zeros=[avg for avg in [sum(zeros[i:i+n])//n for i in range(0,len(zeros),n)] for j in range(n)]
zerosUS1=zeros[0::12]

ones=[avg for avg in [sum(ones[i:i+n])//n for i in range(0,len(ones),n)] for j in range(n)]
onesUS1=ones[0::12]       

twos=[avg for avg in [sum(twos[i:i+n])//n for i in range(0,len(twos),n)] for j in range(n)]
twosUS1=twos[0::12]

threes=[avg for avg in [sum(threes[i:i+n])//n for i in range(0,len(threes),n)] for j in range(n)]
threesUS1=threes[0::12] 

fours=[avg for avg in [sum(fours[i:i+n])//n for i in range(0,len(fours),n)] for j in range(n)]
foursUS1=fours[0::12]

fives=[avg for avg in [sum(fives[i:i+n])//n for i in range(0,len(fives),n)] for j in range(n)]
fivesUS1=fives[0::12]       

sixes=[avg for avg in [sum(sixes[i:i+n])//n for i in range(0,len(sixes),n)] for j in range(n)]
sixesUS1=sixes[0::12]

sevens=[avg for avg in [sum(sevens[i:i+n])//n for i in range(0,len(sevens),n)] for j in range(n)]
sevensUS1=sevens[0::12]

eights=[avg for avg in [sum(eights[i:i+n])//n for i in range(0,len(eights),n)] for j in range(n)]
eightsUS1=eights[0::12]

nines=[avg for avg in [sum(nines[i:i+n])//n for i in range(0,len(nines),n)] for j in range(n)]
ninesUS1=ones[0::12]       

tens=[avg for avg in [sum(tens[i:i+n])//n for i in range(0,len(tens),n)] for j in range(n)]
tensUS1=tens[0::12]

elevens=[avg for avg in [sum(elevens[i:i+n])//n for i in range(0,len(elevens),n)] for j in range(n)]
elevensUS1=elevens[0::12] 

twelves=[avg for avg in [sum(twelves[i:i+n])//n for i in range(0,len(twelves),n)] for j in range(n)]
twelvesUS1=twelves[0::12]

thirteens=[avg for avg in [sum(thirteens[i:i+n])//n for i in range(0,len(thirteens),n)] for j in range(n)]
thirteensUS1=thirteens[0::12]       

fourteens=[avg for avg in [sum(fourteens[i:i+n])//n for i in range(0,len(fourteens),n)] for j in range(n)]
fourteensUS1=fourteens[0::12]

fifteens=[avg for avg in [sum(fifteens[i:i+n])//n for i in range(0,len(fifteens),n)] for j in range(n)]
fifteensUS1=fifteens[0::12]

sixteens=[avg for avg in [sum(sixteens[i:i+n])//n for i in range(0,len(sixteens),n)] for j in range(n)]
sixteensUS1=sixteens[0::12]

seventeens=[avg for avg in [sum(seventeens[i:i+n])//n for i in range(0,len(seventeens),n)] for j in range(n)]
seventeensUS1=seventeens[0::12]

eighteens=[avg for avg in [sum(eighteens[i:i+n])//n for i in range(0,len(eighteens),n)] for j in range(n)]
eighteensUS1=eights[0::12]

nineteens=[avg for avg in [sum(nineteens[i:i+n])//n for i in range(0,len(nineteens),n)] for j in range(n)]
nineteensUS1=ones[0::12]       

twenty=[avg for avg in [sum(twenty[i:i+n])//n for i in range(0,len(twenty),n)] for j in range(n)]
twentyUS1=twenty[0::12]

twentyone=[avg for avg in [sum(twentyone[i:i+n])//n for i in range(0,len(twentyone),n)] for j in range(n)]
twentyoneUS1=twentyone[0::12] 

twentytwo=[avg for avg in [sum(twentytwo[i:i+n])//n for i in range(0,len(twentytwo),n)] for j in range(n)]
twentytwoUS1=twentytwo[0::12]

twentythree=[avg for avg in [sum(twentythree[i:i+n])//n for i in range(0,len(twentythree),n)] for j in range(n)]
twentythreeUS1=twentythree[0::12]

# %%
#Load obs data for all working stations in the BSEC project
AAC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-AAC_AWS_hourly_average.csv")
AAC_AWS=AAC_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
AAC_AWS.index=timeindex
dayaac=AAC_AWS.between_time('10:00:00','00:00:00')
nightaac=AAC_AWS.between_time('1:00:00','9:00:00')

ABL_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-ABL_AWS_hourly_average.csv")
ABL_AWS=ABL_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
ABL_AWS.index=timeindex
dayabl=ABL_AWS.between_time('10:00:00','00:00:00')
nightabl=ABL_AWS.between_time('1:00:00','9:00:00')

AGC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-AGC_AWS_hourly_average.csv")
AGC_AWS=AGC_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
AGC_AWS.index=timeindex
dayagc=AGC_AWS.between_time('10:00:00','00:00:00')
nightagc=AGC_AWS.between_time('1:00:00','9:00:00')

ARK2_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-ARK2_OTT_hourly_average.csv")
ARK2_OTT=ARK2_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
ARK2_OTT.index=timeindex
dayark2=ARK2_OTT.between_time('10:00:00','00:00:00')
nightark2=ARK2_OTT.between_time('1:00:00','9:00:00')

BCC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-BCC_AWS_hourly_average.csv")
BCC_AWS=BCC_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
BCC_AWS.index=timeindex
daybcc=BCC_AWS.between_time('10:00:00','00:00:00')
nightbcc=BCC_AWS.between_time('1:00:00','9:00:00')

CARE_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CARE_OTT_hourly_average.csv")
CARE_OTT=CARE_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
CARE_OTT.index=timeindex
daycare=CARE_OTT.between_time('10:00:00','00:00:00')
nightcare=CARE_OTT.between_time('1:00:00','9:00:00')

CLV_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CLV_AWS_hourly_average.csv")
CLV_AWS=CLV_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
CLV_AWS.index=timeindex
dayclv=CLV_AWS.between_time('10:00:00','00:00:00')
nightclv=CLV_AWS.between_time('1:00:00','9:00:00')

CLV2_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CLV2_AWS_hourly_average.csv")
CLV2_AWS=CLV2_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
CLV2_AWS.index=timeindex
dayclv2=CLV2_AWS.between_time('10:00:00','00:00:00')
nightclv2=CLV2_AWS.between_time('1:00:00','9:00:00')

COV_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-COV_AWS_hourly_average.csv")
COV_AWS=COV_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
COV_AWS.index=timeindex
daycov=COV_AWS.between_time('10:00:00','00:00:00')
nightcov=COV_AWS.between_time('1:00:00','9:00:00')

COV2_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-COV2_AWS_hourly_average.csv")
COV2_AWS=COV2_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
COV2_AWS.index=timeindex
daycov2aws=COV2_AWS.between_time('10:00:00','00:00:00')
nightcov2aws=COV2_AWS.between_time('1:00:00','9:00:00')

COV2_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-COV2_OTT_hourly_average.csv")
COV2_OTT=COV2_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
COV2_OTT.index=timeindex
daycov2ott=COV2_OTT.between_time('10:00:00','00:00:00')
nightcov2ott=COV2_OTT.between_time('1:00:00','9:00:00')

DSG_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-DSG_OTT_hourly_average (2).csv")
DSG_OTT=DSG_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
DSG_OTT.index=timeindex
daydsg=DSG_OTT.between_time('10:00:00','00:00:00')
nightdsg=DSG_OTT.between_time('1:00:00','9:00:00')

FSG_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-FSG_OTT_hourly_average.csv")
FSG_OTT=FSG_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
FSG_OTT.index=timeindex
dayfsg=FSG_OTT.between_time('10:00:00','00:00:00')
nightfsg=FSG_OTT.between_time('1:00:00','9:00:00')

GKF_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-GKF_AWS_hourly_average.csv")
GKF_AWS=GKF_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
GKF_AWS.index=timeindex
daygkf=GKF_AWS.between_time('10:00:00','00:00:00')
nightgkf=GKF_AWS.between_time('1:00:00','9:00:00')

GSA_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-GSA_AWS_hourly_average.csv")
GSA_AWS=GSA_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
GSA_AWS.index=timeindex
daygsa=GSA_AWS.between_time('10:00:00','00:00:00')
nightgsa=GSA_AWS.between_time('1:00:00','9:00:00')

JHU_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-JHU_AWS_hourly_average.csv")
JHU_AWS=JHU_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
JHU_AWS.index=timeindex
dayjhu=JHU_AWS.between_time('10:00:00','00:00:00')
nightjhu=JHU_AWS.between_time('1:00:00','9:00:00')

LGC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-LGC_AWS_hourly_average.csv")
LGC_AWS=LGC_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
LGC_AWS.index=timeindex
daylgc=LGC_AWS.between_time('10:00:00','00:00:00')
nightlgc=LGC_AWS.between_time('1:00:00','9:00:00')

LRT_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-LRT_OTT_hourly_average.csv")
LRT_OTT=LRT_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
LRT_OTT.index=timeindex
daylrt=LRT_OTT.between_time('10:00:00','00:00:00')
nightlrt=LRT_OTT.between_time('1:00:00','9:00:00')

#LRT2_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-LRT_AWS_hourly_average.csv")
#timeindex = pd.date_range(start='2024-06-08',end='2024-08-31-23', freq='H')
#LRT2_AWS.index=timeindex
#daylrt2=LRT2_AWS.between_time('6:00:00','20:00:00')
#nightlrt2=LRT2_AWS.between_time('21:00:00','5:00:00')

MSU_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-MSU_OTT_hourly_average.csv")
MSU_OTT=MSU_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
MSU_OTT.index=timeindex
daymsu=MSU_OTT.between_time('10:00:00','00:00:00')
nightmsu=MSU_OTT.between_time('1:00:00','9:00:00')

MCN_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CMN_OTT_hourly_2024.csv")
MCN_OTT=MCN_OTT[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
MCN_OTT.index=timeindex
daymcn=MCN_OTT.between_time('10:00:00','00:00:00')
nightmcn=MCN_OTT.between_time('1:00:00','9:00:00')

NRP_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-NRP_AWS_hourly_average.csv")
NRP_AWS=NRP_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
NRP_AWS.index=timeindex
daynrp=NRP_AWS.between_time('10:00:00','00:00:00')
nightnrp=NRP_AWS.between_time('1:00:00','9:00:00')

OG_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-OG_AWS_hourly_average.csv")
OG_AWS=OG_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
OG_AWS.index=timeindex
dayog=OG_AWS.between_time('10:00:00','00:00:00')
nightog=OG_AWS.between_time('1:00:00','9:00:00')

SHC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-SHC_AWS_hourly_average.csv")
SHC_AWS=SHC_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
SHC_AWS.index=timeindex
dayshc=SHC_AWS.between_time('10:00:00','00:00:00')
nightshc=SHC_AWS.between_time('1:00:00','9:00:00')

SMF_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-SMF_AWS_hourly_average.csv")
SMF_AWS=SMF_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-08-31-23', freq='H')
SMF_AWS.index=timeindex
daysmf=SMF_AWS.between_time('10:00:00','00:00:00')
nightsmf=SMF_AWS.between_time('1:00:00','9:00:00')

UBC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-UBC_AWS_hourly_average.csv")
UBC_AWS=UBC_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-09-01 00:00:00', freq='H')
UBC_AWS.index=timeindex
dayubc=UBC_AWS.between_time('10:00:00','00:00:00')
nightubc=UBC_AWS.between_time('1:00:00','9:00:00')

WHE_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-WHE_AWS_hourly_average.csv")
WHE_AWS=WHE_AWS[12:]
timeindex = pd.date_range(start='2024-06-01-12:00',end='2024-09-01-00', freq='H')
WHE_AWS.index=timeindex
daywhe=WHE_AWS.between_time('10:00:00','00:00:00')
nightwhe=WHE_AWS.between_time('1:00:00','9:00:00')

# %%
dayaac=dayaac['humidityAvg']
dayabl=dayabl['humidityAvg']
dayagc=dayagc['humidityAvg']
dayark2=dayark2['humidityAvg']
daybcc=daybcc['humidityAvg']
daycare=daycare['humidityAvg']
dayclv=dayclv['humidityAvg']
dayclv2=dayclv2['humidityAvg']
daycov=daycov['humidityAvg']
daycov2aws=daycov2aws['humidityAvg']
daycov2ott=daycov2ott['humidityAvg']
daydsg=daydsg['humidityAvg']
dayfsg=dayfsg['humidityAvg']
daygkf=daygkf['humidityAvg']
daygsa=daygsa['humidityAvg']
dayjhu=dayjhu['humidityAvg']
daylgc=daylgc['humidityAvg']
daylrt=daylrt['humidityAvg']
daymsu=daymsu['humidityAvg']
daymcn=daymcn['humidityAvg']
daynrp=daynrp['humidityAvg']
dayog=dayog['humidityAvg']
dayshc=dayshc['humidityAvg']
daysmf=daysmf['humidityAvg']
dayubc=dayubc['humidityAvg']
daywhe=daywhe['humidityAvg']

nightaac=nightaac['humidityAvg']
nightabl=nightabl['humidityAvg']
nightagc=nightagc['humidityAvg']
nightark2=nightark2['humidityAvg']
nightbcc=nightbcc['humidityAvg']
nightcare=nightcare['humidityAvg']
nightclv=nightclv['humidityAvg']
nightclv2=nightclv2['humidityAvg']
nightcov=nightcov['humidityAvg']
nightcov2aws=nightcov2aws['humidityAvg']
nightcov2ott=nightcov2ott['humidityAvg']
nightdsg=nightdsg['humidityAvg']
nightfsg=nightfsg['humidityAvg']
nightgkf=nightgkf['humidityAvg']
nightgsa=nightgsa['humidityAvg']
nightjhu=nightjhu['humidityAvg']
nightlgc=nightlgc['humidityAvg']
nightlrt=nightlrt['humidityAvg']
nightmsu=nightmsu['humidityAvg']
nightmcn=nightmcn['humidityAvg']
nightnrp=nightnrp['humidityAvg']
nightog=nightog['humidityAvg']
nightshc=nightshc['humidityAvg']
nightsmf=nightsmf['humidityAvg']
nightubc=nightubc['humidityAvg']
nightwhe=nightwhe['humidityAvg']

# %%
station_list_day=[dayaac,dayabl,dayagc,dayark2,daybcc,daycare,dayclv,dayclv2,daycov,daycov2aws,daycov2ott,daydsg,dayfsg,daygkf,daygsa,dayjhu,daylgc,daymsu,daymcn,daynrp,dayog,dayshc,daysmf,daywhe,dayClarkTMP]
station_list_night=[nightaac,nightabl,nightagc,nightark2,nightbcc,nightcare,nightclv,nightclv2,nightcov,nightcov2aws,nightcov2ott,nightdsg,nightfsg,nightgkf,nightgsa,nightjhu,nightlgc,nightmsu,nightmcn,nightnrp,nightog,nightshc,nightsmf,nightwhe,nightClarkTMP]
maryland_I70=[twentyoneI70,twentytwoI70,twentythreeI70,zerosI70,onesI70,twosI70,threesI70,foursI70,fivesI70,sixesI70,sevensI70,eightsI70,ninesI70,tensI70,elevensI70,twelvesI70,thirteensI70,fourteensI70,fifteensI70,sixteensI70,seventeensI70,eighteensI70,nineteensI70,twentyI70]
maryland_US1=[twentyoneUS1,twentytwoUS1,twentythreeUS1,zerosUS1,onesUS1,twosUS1,threesUS1,foursUS1,fivesUS1,sixesUS1,sevensUS1,eightsUS1,ninesUS1,tensUS1,elevensUS1,twelvesUS1,thirteensUS1,fourteensUS1,fifteensUS1,sixteensUS1,seventeensUS1,eighteensUS1,nineteensUS1,twentyUS1]
marylands=[maryland_I70,maryland_US1]

# %%
hour1=[]
hour2=[]
hour3=[]
hour4=[]
hour5=[]
hour6=[]
hour7=[]
hour8=[]
hour9=[]
hour10=[]
hour11=[]
hour12=[]
hour13=[]
hour14=[]
hour15=[]
hour16=[]
hour17=[]
hour18=[]
hour19=[]
hour20=[]
hour21=[]
hour22=[]
hour23=[]
hour00=[]
for i in range(0,25):
    hour1.append(station_list_night[i].at_time('1:00:00'))
    hour2.append(station_list_night[i].at_time('2:00:00'))
    hour3.append(station_list_night[i].at_time('3:00:00'))
    hour4.append(station_list_night[i].at_time('4:00:00'))
    hour5.append(station_list_night[i].at_time('5:00:00'))
    hour6.append(station_list_night[i].at_time('6:00:00'))
    hour7.append(station_list_night[i].at_time('7:00:00'))
    hour8.append(station_list_night[i].at_time('8:00:00'))
    hour9.append(station_list_night[i].at_time('9:00:00'))
    hour10.append(station_list_day[i].at_time('10:00:00'))
    hour11.append(station_list_day[i].at_time('11:00:00'))
    hour12.append(station_list_day[i].at_time('12:00:00'))
    hour13.append(station_list_day[i].at_time('13:00:00'))
    hour14.append(station_list_day[i].at_time('14:00:00'))
    hour15.append(station_list_day[i].at_time('15:00:00'))
    hour16.append(station_list_day[i].at_time('16:00:00'))
    hour17.append(station_list_day[i].at_time('17:00:00'))
    hour18.append(station_list_day[i].at_time('18:00:00'))
    hour19.append(station_list_day[i].at_time('19:00:00'))
    hour20.append(station_list_day[i].at_time('20:00:00'))
    hour21.append(station_list_day[i].at_time('21:00:00'))
    hour22.append(station_list_day[i].at_time('22:00:00'))
    hour23.append(station_list_day[i].at_time('23:00:00'))
    hour00.append(station_list_day[i].at_time('00:00:00'))
    
    
hour1T=[]
hour2T=[]
hour3T=[]
hour4T=[]
hour5T=[]
hour6T=[]
hour7T=[]
hour8T=[]
hour9T=[]
hour10T=[]
hour11T=[]
hour12T=[]
hour13T=[]
hour14T=[]
hour15T=[]
hour16T=[]
hour17T=[]
hour18T=[]
hour19T=[]
hour20T=[]
hour21T=[]
hour22T=[]
hour23T=[]
hour00T=[]
for i in range(0,25):
    hour1T.append(hour1[i][0:89])
    hour2T.append(hour2[i][0:89])
    hour3T.append(hour3[i][0:89])
    hour4T.append(hour4[i][0:89])
    hour5T.append(hour5[i][0:89])
    hour6T.append(hour6[i][0:89])
    hour7T.append(hour7[i][0:89])
    hour8T.append(hour8[i][0:89])
    hour9T.append(hour9[i][0:89])
    hour10T.append(hour10[i][0:89])
    hour11T.append(hour11[i][0:89])
    hour12T.append(hour12[i][0:89])
    hour13T.append(hour13[i][0:89])
    hour14T.append(hour14[i][0:89])
    hour15T.append(hour15[i][0:89])
    hour16T.append(hour16[i][0:89])
    hour17T.append(hour17[i][0:89])
    hour18T.append(hour18[i][0:89])
    hour19T.append(hour19[i][0:89])
    hour20T.append(hour20[i][0:89])
    hour21T.append(hour21[i][0:89])
    hour22T.append(hour22[i][0:89])
    hour23T.append(hour23[i][0:89])
    hour00T.append(hour00[i][0:89])

# %%
#items=[0]
hour1I=[]
hour2I=[]
hour3I=[]
hour4I=[]
hour5I=[]
hour6I=[]
hour7I=[]
hour8I=[]
hour9I=[]
hour10I=[]
hour11I=[]
hour12I=[]
hour13I=[]
hour14I=[]
hour15I=[]
hour16I=[]
hour17I=[]
hour18I=[]
hour19I=[]
hour20I=[]
hour21I=[]
hour22I=[]
hour23I=[]
hour00I=[]
for iii in range (0,89): 
    hour00I.append(maryland_I70[3][iii])
    hour1I.append(maryland_I70[4][iii])
    hour2I.append(maryland_I70[5][iii])
    hour3I.append(maryland_I70[6][iii])
    hour4I.append(maryland_I70[7][iii])
    hour5I.append(maryland_I70[8][iii])
    hour6I.append(maryland_I70[9][iii])
    hour7I.append(maryland_I70[10][iii])
    hour8I.append(maryland_I70[11][iii])
    hour9I.append(maryland_I70[12][iii])
    hour10I.append(maryland_I70[13][iii])
    hour11I.append(maryland_I70[14][iii])
    hour12I.append(maryland_I70[15][iii])
    hour13I.append(maryland_I70[16][iii])
    hour14I.append(maryland_I70[17][iii])
    hour15I.append(maryland_I70[18][iii])
    hour16I.append(maryland_I70[19][iii])
    hour17I.append(maryland_I70[20][iii])
    hour18I.append(maryland_I70[21][iii])
    hour19I.append(maryland_I70[22][iii])
    hour20I.append(maryland_I70[23][iii])
    hour21I.append(maryland_I70[0][iii])
    hour22I.append(maryland_I70[1][iii])
    hour23I.append(maryland_I70[2][iii])

# %%
hour1U=[]
hour2U=[]
hour3U=[]
hour4U=[]
hour5U=[]
hour6U=[]
hour7U=[]
hour8U=[]
hour9U=[]
hour10U=[]
hour11U=[]
hour12U=[]
hour13U=[]
hour14U=[]
hour15U=[]
hour16U=[]
hour17U=[]
hour18U=[]
hour19U=[]
hour20U=[]
hour21U=[]
hour22U=[]
hour23U=[]
hour00U=[]
for iii in range (0,89): 
    hour00U.append(maryland_US1[3][iii])
    hour1U.append(maryland_US1[4][iii])
    hour2U.append(maryland_US1[5][iii])
    hour3U.append(maryland_US1[6][iii])
    hour4U.append(maryland_US1[7][iii])
    hour5U.append(maryland_US1[8][iii])
    hour6U.append(maryland_US1[9][iii])
    hour7U.append(maryland_US1[10][iii])
    hour8U.append(maryland_US1[11][iii])
    hour9U.append(maryland_US1[12][iii])
    hour10U.append(maryland_US1[13][iii])
    hour11U.append(maryland_US1[14][iii])
    hour12U.append(maryland_US1[15][iii])
    hour13U.append(maryland_US1[16][iii])
    hour14U.append(maryland_US1[17][iii])
    hour15U.append(maryland_US1[18][iii])
    hour16U.append(maryland_US1[19][iii])
    hour17U.append(maryland_US1[20][iii])
    hour18U.append(maryland_US1[21][iii])
    hour19U.append(maryland_US1[22][iii])
    hour20U.append(maryland_US1[23][iii])
    hour21U.append(maryland_US1[0][iii])
    hour22U.append(maryland_US1[1][iii])
    hour23U.append(maryland_US1[2][iii])

# %%
hour00T.append(hour00I[0:89])
hour00T.append(hour00U[0:89])

hour1T.append(hour1I[0:89])
hour1T.append(hour1U[0:89])

hour2T.append(hour2I[0:89])
hour2T.append(hour2U[0:89])

hour3T.append(hour3I[0:89])
hour3T.append(hour3U[0:89])

hour4T.append(hour4I[0:89])
hour4T.append(hour4U[0:89])

hour5T.append(hour5I[0:89])
hour5T.append(hour5U[0:89])

hour6T.append(hour6I[0:89])
hour6T.append(hour6U[0:89])

hour7T.append(hour7I[0:89])
hour7T.append(hour7U[0:89])

hour8T.append(hour8I[0:89])
hour8T.append(hour8U[0:89])

hour9T.append(hour9I[0:89])
hour9T.append(hour9U[0:89])

hour10T.append(hour10I[0:89])
hour10T.append(hour10U[0:89])

hour11T.append(hour11I[0:89])
hour11T.append(hour11U[0:89])

hour12T.append(hour12I[0:89])
hour12T.append(hour12U[0:89])

hour13T.append(hour13I[0:89])
hour13T.append(hour13U[0:89])

hour14T.append(hour14I[0:89])
hour14T.append(hour14U[0:89])

hour15T.append(hour15I[0:89])
hour15T.append(hour15U[0:89])

hour16T.append(hour16I[0:89])
hour16T.append(hour16U[0:89])

hour17T.append(hour17I[0:89])
hour17T.append(hour17U[0:89])

hour18T.append(hour18I[0:89])
hour18T.append(hour18U[0:89])

hour19T.append(hour19I[0:89])
hour19T.append(hour19U[0:89])

hour20T.append(hour20I[0:89])
hour20T.append(hour20U[0:89])

hour21T.append(hour21I[0:89])
hour21T.append(hour21U[0:89])

hour22T.append(hour22I[0:89])
hour22T.append(hour22U[0:89])

hour23T.append(hour23I[0:89])
hour23T.append(hour23U[0:89])

# %%
# Define the data arrays for each hour
hours_data = [hour00T, hour1T, hour2T, hour3T, hour4T, hour5T, hour6T, hour7T, hour8T, hour9T, 
              hour10T, hour11T, hour12T, hour13T, hour14T, hour15T, hour16T, hour17T, hour18T, hour19T,
              hour20T, hour21T, hour22T, hour23T]

# Define indices for each category
indices_urban = [11, 2, 5, 18, 23, 16, 0, 4, 14, 17]
indices_suburban = [3, 15, 1, 20, 22, 13, 21, 12]
indices_rural = [8, 9, 10, 6, 7, 19, 24,25,26]

urban_sum=[]
urban_average=[]

suburban_sum=[]
suburban_average=[]

rural_sum=[]
rural_average=[]

for ii in range(0,24):
    for i in range(0,89):
        urban_sum.append(hours_data[ii][11][i]+hours_data[ii][2][i]+hours_data[ii][5][i]+hours_data[ii][18][i]+hours_data[ii][23][i]+hours_data[ii][16][ii]+hours_data[ii][0][i]+hours_data[ii][4][i]+hours_data[ii][14][i]+hours_data[ii][17][i])
        suburban_sum.append(hours_data[ii][3][i]+hours_data[ii][15][i]+hours_data[ii][1][i]+hours_data[ii][20][i]+hours_data[ii][22][i]+hours_data[ii][13][ii]+hours_data[ii][21][i]+hours_data[ii][12][i])
        rural_sum.append(hours_data[ii][8][i]+hours_data[ii][9][i]+hours_data[ii][10][i]+hours_data[ii][6][i]+hours_data[ii][7][i]+hours_data[ii][19][ii]+hours_data[ii][24][i]+hours_data[ii][25][i]+hours_data[ii][26][i])
    
for iii in range(0,len(urban_sum)):
    rural_average.append(rural_sum[iii]/10) #numbers are the number of indicies in that group
    suburban_average.append(suburban_sum[iii]/8)
    urban_average.append(urban_sum[iii]/9)

# %%
urbanhour00=urban_average[0:89]
suburbanhour00=suburban_average[0:89]
ruralhour00=rural_average[0:89]

urbanhour1=urban_average[90:179]
suburbanhour1=suburban_average[90:179]
ruralhour1=rural_average[90:179]

urbanhour2=urban_average[180:269]
suburbanhour2=suburban_average[180:269]
ruralhour2=rural_average[180:269]

urbanhour3=urban_average[270:359]
suburbanhour3=suburban_average[270:359]
ruralhour3=rural_average[270:359]

urbanhour4=urban_average[360:449]
suburbanhour4=suburban_average[360:449]
ruralhour4=rural_average[360:449]

urbanhour5=urban_average[450:539]
suburbanhour5=suburban_average[450:539]
ruralhour5=rural_average[450:539]

urbanhour6=urban_average[540:629]
suburbanhour6=suburban_average[540:629]
ruralhour6=rural_average[540:629]

urbanhour7=urban_average[630:719]
suburbanhour7=suburban_average[630:719]
ruralhour7=rural_average[630:719]

urbanhour8=urban_average[720:809]
suburbanhour8=suburban_average[720:809]
ruralhour8=rural_average[720:809]

urbanhour9=urban_average[810:899]
suburbanhour9=suburban_average[810:899]
ruralhour9=rural_average[810:899]

urbanhour10=urban_average[900:989]
suburbanhour10=suburban_average[900:989]
ruralhour10=rural_average[900:989]

urbanhour11=urban_average[990:1079]
suburbanhour11=suburban_average[990:1079]
ruralhour11=rural_average[990:1079]

urbanhour12=urban_average[1080:1169]
suburbanhour12=suburban_average[1080:1169]
ruralhour12=rural_average[1080:1169]

urbanhour13=urban_average[1170:1259]
suburbanhour13=suburban_average[1170:1259]
ruralhour13=rural_average[1170:1259]

urbanhour14=urban_average[1260:1349]
suburbanhour14=suburban_average[1260:1349]
ruralhour14=rural_average[1260:1349]

urbanhour15=urban_average[1350:1439]
suburbanhour15=suburban_average[1350:1439]
ruralhour15=rural_average[1350:1439]

urbanhour16=urban_average[1440:1529]
suburbanhour16=suburban_average[1440:1529]
ruralhour16=rural_average[1440:1529]

urbanhour17=urban_average[1530:1619]
suburbanhour17=suburban_average[1530:1619]
ruralhour17=rural_average[1530:1619]

urbanhour18=urban_average[1620:1709]
suburbanhour18=suburban_average[1620:1709]
ruralhour18=rural_average[1620:1709]

urbanhour19=urban_average[1710:1799]
suburbanhour19=suburban_average[1710:1799]
ruralhour19=rural_average[1710:1799]

urbanhour20=urban_average[1800:1889]
suburbanhour20=suburban_average[1800:1889]
ruralhour20=rural_average[1800:1889]

urbanhour21=urban_average[1890:1979]
suburbanhour21=suburban_average[1890:1979]
ruralhour21=rural_average[1890:1979]

urbanhour22=urban_average[1980:2069]
suburbanhour22=suburban_average[1980:2069]
ruralhour22=rural_average[1980:2069]

urbanhour23=urban_average[2070:2159]
suburbanhour23=suburban_average[2070:2159]
ruralhour23=rural_average[2070:2159]

# %%
fcst00urban = [
    fcst00hour00urban, fcst00hour01urban, fcst00hour02urban, fcst00hour03urban, fcst00hour04urban,
    fcst00hour05urban, fcst00hour06urban, fcst00hour07urban, fcst00hour08urban, fcst00hour09urban,
    fcst00hour10urban, fcst00hour11urban, fcst00hour12urban, fcst00hour13urban, fcst00hour14urban,
    fcst00hour15urban, fcst00hour16urban, fcst00hour17urban, fcst00hour18urban, fcst00hour19urban,
    fcst00hour20urban, fcst00hour21urban, fcst00hour22urban, fcst00hour23urban
]

fcst06urban = [
    fcst06hour00urban, fcst06hour01urban, fcst06hour02urban, fcst06hour03urban, fcst06hour04urban,
    fcst06hour05urban, fcst06hour06urban, fcst06hour07urban, fcst06hour08urban, fcst06hour09urban,
    fcst06hour10urban, fcst06hour11urban, fcst06hour12urban, fcst06hour13urban, fcst06hour14urban,
    fcst06hour15urban, fcst06hour16urban, fcst06hour17urban, fcst06hour18urban, fcst06hour19urban,
    fcst06hour20urban, fcst06hour21urban, fcst06hour22urban, fcst06hour23urban
]

fcst12urban = [
    fcst12hour00urban, fcst12hour01urban, fcst12hour02urban, fcst12hour03urban, fcst12hour04urban,
    fcst12hour05urban, fcst12hour06urban, fcst12hour07urban, fcst12hour08urban, fcst12hour09urban,
    fcst12hour10urban, fcst12hour11urban, fcst12hour12urban, fcst12hour13urban, fcst12hour14urban,
    fcst12hour15urban, fcst12hour16urban, fcst12hour17urban, fcst12hour18urban, fcst12hour19urban,
    fcst12hour20urban, fcst12hour21urban, fcst12hour22urban, fcst12hour23urban
]

fcst18urban = [
    fcst18hour00urban, fcst18hour01urban, fcst18hour02urban, fcst18hour03urban, fcst18hour04urban,
    fcst18hour05urban, fcst18hour06urban, fcst18hour07urban, fcst18hour08urban, fcst18hour09urban,
    fcst18hour10urban, fcst18hour11urban, fcst18hour12urban, fcst18hour13urban, fcst18hour14urban,
    fcst18hour15urban, fcst18hour16urban, fcst18hour17urban, fcst18hour18urban, fcst18hour19urban,
    fcst18hour20urban, fcst18hour21urban, fcst18hour22urban, fcst18hour23urban
]

# %%
fcst00suburban = [
    fcst00hour00suburban, fcst00hour01suburban, fcst00hour02suburban, fcst00hour03suburban, fcst00hour04suburban,
    fcst00hour05suburban, fcst00hour06suburban, fcst00hour07suburban, fcst00hour08suburban, fcst00hour09suburban,
    fcst00hour10suburban, fcst00hour11suburban, fcst00hour12suburban, fcst00hour13suburban, fcst00hour14suburban,
    fcst00hour15suburban, fcst00hour16suburban, fcst00hour17suburban, fcst00hour18suburban, fcst00hour19suburban,
    fcst00hour20suburban, fcst00hour21suburban, fcst00hour22suburban, fcst00hour23suburban
]

fcst06suburban = [
    fcst06hour00suburban, fcst06hour01suburban, fcst06hour02suburban, fcst06hour03suburban, fcst06hour04suburban,
    fcst06hour05suburban, fcst06hour06suburban, fcst06hour07suburban, fcst06hour08suburban, fcst06hour09suburban,
    fcst06hour10suburban, fcst06hour11suburban, fcst06hour12suburban, fcst06hour13suburban, fcst06hour14suburban,
    fcst06hour15suburban, fcst06hour16suburban, fcst06hour17suburban, fcst06hour18suburban, fcst06hour19suburban,
    fcst06hour20suburban, fcst06hour21suburban, fcst06hour22suburban, fcst06hour23suburban
]

fcst12suburban = [
    fcst12hour00suburban, fcst12hour01suburban, fcst12hour02suburban, fcst12hour03suburban, fcst12hour04suburban,
    fcst12hour05suburban, fcst12hour06suburban, fcst12hour07suburban, fcst12hour08suburban, fcst12hour09suburban,
    fcst12hour10suburban, fcst12hour11suburban, fcst12hour12suburban, fcst12hour13suburban, fcst12hour14suburban,
    fcst12hour15suburban, fcst12hour16suburban, fcst12hour17suburban, fcst12hour18suburban, fcst12hour19suburban,
    fcst12hour20suburban, fcst12hour21suburban, fcst12hour22suburban, fcst12hour23suburban
]

fcst18suburban = [
    fcst18hour00suburban, fcst18hour01suburban, fcst18hour02suburban, fcst18hour03suburban, fcst18hour04suburban,
    fcst18hour05suburban, fcst18hour06suburban, fcst18hour07suburban, fcst18hour08suburban, fcst18hour09suburban,
    fcst18hour10suburban, fcst18hour11suburban, fcst18hour12suburban, fcst18hour13suburban, fcst18hour14suburban,
    fcst18hour15suburban, fcst18hour16suburban, fcst18hour17suburban, fcst18hour18suburban, fcst18hour19suburban,
    fcst18hour20suburban, fcst18hour21suburban, fcst18hour22suburban, fcst18hour23suburban
]

# %%
fcst00rural = [
    fcst00hour00rural, fcst00hour01rural, fcst00hour02rural, fcst00hour03rural, fcst00hour04rural,
    fcst00hour05rural, fcst00hour06rural, fcst00hour07rural, fcst00hour08rural, fcst00hour09rural,
    fcst00hour10rural, fcst00hour11rural, fcst00hour12rural, fcst00hour13rural, fcst00hour14rural,
    fcst00hour15rural, fcst00hour16rural, fcst00hour17rural, fcst00hour18rural, fcst00hour19rural,
    fcst00hour20rural, fcst00hour21rural, fcst00hour22rural, fcst00hour23rural
]

fcst06rural = [
    fcst06hour00rural, fcst06hour01rural, fcst06hour02rural, fcst06hour03rural, fcst06hour04rural,
    fcst06hour05rural, fcst06hour06rural, fcst06hour07rural, fcst06hour08rural, fcst06hour09rural,
    fcst06hour10rural, fcst06hour11rural, fcst06hour12rural, fcst06hour13rural, fcst06hour14rural,
    fcst06hour15rural, fcst06hour16rural, fcst06hour17rural, fcst06hour18rural, fcst06hour19rural,
    fcst06hour20rural, fcst06hour21rural, fcst06hour22rural, fcst06hour23rural
]

fcst12rural = [
    fcst12hour00rural, fcst12hour01rural, fcst12hour02rural, fcst12hour03rural, fcst12hour04rural,
    fcst12hour05rural, fcst12hour06rural, fcst12hour07rural, fcst12hour08rural, fcst12hour09rural,
    fcst12hour10rural, fcst12hour11rural, fcst12hour12rural, fcst12hour13rural, fcst12hour14rural,
    fcst12hour15rural, fcst12hour16rural, fcst12hour17rural, fcst12hour18rural, fcst12hour19rural,
    fcst12hour20rural, fcst12hour21rural, fcst12hour22rural, fcst12hour23rural
]

fcst18rural = [
    fcst18hour00rural, fcst18hour01rural, fcst18hour02rural, fcst18hour03rural, fcst18hour04rural,
    fcst18hour05rural, fcst18hour06rural, fcst18hour07rural, fcst18hour08rural, fcst18hour09rural,
    fcst18hour10rural, fcst18hour11rural, fcst18hour12rural, fcst18hour13rural, fcst18hour14rural,
    fcst18hour15rural, fcst18hour16rural, fcst18hour17rural, fcst18hour18rural, fcst18hour19rural,
    fcst18hour20rural, fcst18hour21rural, fcst18hour22rural, fcst18hour23rural
]

# %%
fcst12urbanHW1=[]
fcst12suburbanHW1=[]
fcst12ruralHW1=[]

fcst12urbanHW2=[]
fcst12suburbanHW2=[]
fcst12ruralHW2=[]

fcst12urbanHW3=[]
fcst12suburbanHW3=[]
fcst12ruralHW3=[]

fcst12urbanHW4=[]
fcst12suburbanHW4=[]
fcst12ruralHW4=[]

fcst12urbanHW5=[]
fcst12suburbanHW5=[]
fcst12ruralHW5=[]

fcst12urbanHW6=[]
fcst12suburbanHW6=[]
fcst12ruralHW6=[]

fcst12urbanHW7=[]
fcst12suburbanHW7=[]
fcst12ruralHW7=[]

fcst12urbanHW8=[]
fcst12suburbanHW8=[]
fcst12ruralHW8=[]

for ii in range(0,24):
    fcst12urbanHW1.append(fcst12urban[ii][8:11])
    fcst12suburbanHW1.append(fcst12suburban[ii][8:11])
    fcst12ruralHW1.append(fcst12rural[ii][8:11])
    
    fcst12urbanHW2.append(fcst12urban[ii][29:32])
    fcst12suburbanHW2.append(fcst12suburban[ii][29:32])
    fcst12ruralHW2.append(fcst12rural[ii][29:32])
    
    fcst12urbanHW3.append(fcst12urban[ii][46:49])
    fcst12suburbanHW3.append(fcst12suburban[ii][46:49])
    fcst12ruralHW3.append(fcst12rural[ii][46:49])
    
    fcst12urbanHW4.append(fcst12urban[ii][52:55])
    fcst12suburbanHW4.append(fcst12suburban[ii][52:55])
    fcst12ruralHW4.append(fcst12rural[ii][52:55])
    
    fcst12urbanHW5.append(fcst12urban[ii][70:74])
    fcst12suburbanHW5.append(fcst12suburban[ii][70:74])
    fcst12ruralHW5.append(fcst12rural[ii][70:74])
    
    fcst12urbanHW6.append(fcst12urban[ii][76:84])
    fcst12suburbanHW6.append(fcst12suburban[ii][76:84])
    fcst12ruralHW6.append(fcst12rural[ii][76:84])

# %%
# Coolwave 1 [8:11]
urbansHW1 = [urbanhour00[8:11], urbanhour1[8:11], urbanhour2[8:11], urbanhour3[8:11], urbanhour4[8:11], urbanhour5[8:11], urbanhour6[8:11], urbanhour7[8:11], urbanhour8[8:11], urbanhour9[8:11], urbanhour10[8:11], urbanhour11[8:11], urbanhour12[8:11], urbanhour13[8:11], urbanhour14[8:11], urbanhour15[8:11], urbanhour16[8:11], urbanhour17[8:11], urbanhour18[8:11], urbanhour19[8:11], urbanhour20[8:11], urbanhour21[8:11], urbanhour22[8:11], urbanhour23[8:11]]
suburbansHW1 = [suburbanhour00[8:11], suburbanhour1[8:11], suburbanhour2[8:11], suburbanhour3[8:11], suburbanhour4[8:11], suburbanhour5[8:11], suburbanhour6[8:11], suburbanhour7[8:11], suburbanhour8[8:11], suburbanhour9[8:11], suburbanhour10[8:11], suburbanhour11[8:11], suburbanhour12[8:11], suburbanhour13[8:11], suburbanhour14[8:11], suburbanhour15[8:11], suburbanhour16[8:11], suburbanhour17[8:11], suburbanhour18[8:11], suburbanhour19[8:11], suburbanhour20[8:11], suburbanhour21[8:11], suburbanhour22[8:11], suburbanhour23[8:11]]
ruralsHW1 = [ruralhour00[8:11], ruralhour1[8:11], ruralhour2[8:11], ruralhour3[8:11], ruralhour4[8:11], ruralhour5[8:11], ruralhour6[8:11], ruralhour7[8:11], ruralhour8[8:11], ruralhour9[8:11], ruralhour10[8:11], ruralhour11[8:11], ruralhour12[8:11], ruralhour13[8:11], ruralhour14[8:11], ruralhour15[8:11], ruralhour16[8:11], ruralhour17[8:11], ruralhour18[8:11], ruralhour19[8:11], ruralhour20[8:11], ruralhour21[8:11], ruralhour22[8:11], ruralhour23[8:11]]

# Coolwave 2 [29:32]
urbansHW2 = [urbanhour00[29:32], urbanhour1[29:32], urbanhour2[29:32], urbanhour3[29:32], urbanhour4[29:32], urbanhour5[29:32], urbanhour6[29:32], urbanhour7[29:32], urbanhour8[29:32], urbanhour9[29:32], urbanhour10[29:32], urbanhour11[29:32], urbanhour12[29:32], urbanhour13[29:32], urbanhour14[29:32], urbanhour15[29:32], urbanhour16[29:32], urbanhour17[29:32], urbanhour18[29:32], urbanhour19[29:32], urbanhour20[29:32], urbanhour21[29:32], urbanhour22[29:32], urbanhour23[29:32]]
suburbansHW2 = [suburbanhour00[29:32], suburbanhour1[29:32], suburbanhour2[29:32], suburbanhour3[29:32], suburbanhour4[29:32], suburbanhour5[29:32], suburbanhour6[29:32], suburbanhour7[29:32], suburbanhour8[29:32], suburbanhour9[29:32], suburbanhour10[29:32], suburbanhour11[29:32], suburbanhour12[29:32], suburbanhour13[29:32], suburbanhour14[29:32], suburbanhour15[29:32], suburbanhour16[29:32], suburbanhour17[29:32], suburbanhour18[29:32], suburbanhour19[29:32], suburbanhour20[29:32], suburbanhour21[29:32], suburbanhour22[29:32], suburbanhour23[29:32]]
ruralsHW2 = [ruralhour00[29:32], ruralhour1[29:32], ruralhour2[29:32], ruralhour3[29:32], ruralhour4[29:32], ruralhour5[29:32], ruralhour6[29:32], ruralhour7[29:32], ruralhour8[29:32], ruralhour9[29:32], ruralhour10[29:32], ruralhour11[29:32], ruralhour12[29:32], ruralhour13[29:32], ruralhour14[29:32], ruralhour15[29:32], ruralhour16[29:32], ruralhour17[29:32], ruralhour18[29:32], ruralhour19[29:32], ruralhour20[29:32], ruralhour21[29:32], ruralhour22[29:32], ruralhour23[29:32]]

# Coolwave 3 [46:49]
urbansHW3 = [urbanhour00[46:49], urbanhour1[46:49], urbanhour2[46:49], urbanhour3[46:49], urbanhour4[46:49], urbanhour5[46:49], urbanhour6[46:49], urbanhour7[46:49], urbanhour8[46:49], urbanhour9[46:49], urbanhour10[46:49], urbanhour11[46:49], urbanhour12[46:49], urbanhour13[46:49], urbanhour14[46:49], urbanhour15[46:49], urbanhour16[46:49], urbanhour17[46:49], urbanhour18[46:49], urbanhour19[46:49], urbanhour20[46:49], urbanhour21[46:49], urbanhour22[46:49], urbanhour23[46:49]]
suburbansHW3 = [suburbanhour00[46:49], suburbanhour1[46:49], suburbanhour2[46:49], suburbanhour3[46:49], suburbanhour4[46:49], suburbanhour5[46:49], suburbanhour6[46:49], suburbanhour7[46:49], suburbanhour8[46:49], suburbanhour9[46:49], suburbanhour10[46:49], suburbanhour11[46:49], suburbanhour12[46:49], suburbanhour13[46:49], suburbanhour14[46:49], suburbanhour15[46:49], suburbanhour16[46:49], suburbanhour17[46:49], suburbanhour18[46:49], suburbanhour19[46:49], suburbanhour20[46:49], suburbanhour21[46:49], suburbanhour22[46:49], suburbanhour23[46:49]]
ruralsHW3 = [ruralhour00[46:49], ruralhour1[46:49], ruralhour2[46:49], ruralhour3[46:49], ruralhour4[46:49], ruralhour5[46:49], ruralhour6[46:49], ruralhour7[46:49], ruralhour8[46:49], ruralhour9[46:49], ruralhour10[46:49], ruralhour11[46:49], ruralhour12[46:49], ruralhour13[46:49], ruralhour14[46:49], ruralhour15[46:49], ruralhour16[46:49], ruralhour17[46:49], ruralhour18[46:49], ruralhour19[46:49], ruralhour20[46:49], ruralhour21[46:49], ruralhour22[46:49], ruralhour23[46:49]]

# Coolwave 4 [52:55]
urbansHW4 = [urbanhour00[52:55], urbanhour1[52:55], urbanhour2[52:55], urbanhour3[52:55], urbanhour4[52:55], urbanhour5[52:55], urbanhour6[52:55], urbanhour7[52:55], urbanhour8[52:55], urbanhour9[52:55], urbanhour10[52:55], urbanhour11[52:55], urbanhour12[52:55], urbanhour13[52:55], urbanhour14[52:55], urbanhour15[52:55], urbanhour16[52:55], urbanhour17[52:55], urbanhour18[52:55], urbanhour19[52:55], urbanhour20[52:55], urbanhour21[52:55], urbanhour22[52:55], urbanhour23[52:55]]
suburbansHW4 = [suburbanhour00[52:55], suburbanhour1[52:55], suburbanhour2[52:55], suburbanhour3[52:55], suburbanhour4[52:55], suburbanhour5[52:55], suburbanhour6[52:55], suburbanhour7[52:55], suburbanhour8[52:55], suburbanhour9[52:55], suburbanhour10[52:55], suburbanhour11[52:55], suburbanhour12[52:55], suburbanhour13[52:55], suburbanhour14[52:55], suburbanhour15[52:55], suburbanhour16[52:55], suburbanhour17[52:55], suburbanhour18[52:55], suburbanhour19[52:55], suburbanhour20[52:55], suburbanhour21[52:55], suburbanhour22[52:55], suburbanhour23[52:55]]
ruralsHW4 = [ruralhour00[52:55], ruralhour1[52:55], ruralhour2[52:55], ruralhour3[52:55], ruralhour4[52:55], ruralhour5[52:55], ruralhour6[52:55], ruralhour7[52:55], ruralhour8[52:55], ruralhour9[52:55], ruralhour10[52:55], ruralhour11[52:55], ruralhour12[52:55], ruralhour13[52:55], ruralhour14[52:55], ruralhour15[52:55], ruralhour16[52:55], ruralhour17[52:55], ruralhour18[52:55], ruralhour19[52:55], ruralhour20[52:55], ruralhour21[52:55], ruralhour22[52:55], ruralhour23[52:55]]

# Coolwave 5 [70:74]
urbansHW5 = [urbanhour00[70:74], urbanhour1[70:74], urbanhour2[70:74], urbanhour3[70:74], urbanhour4[70:74], urbanhour5[70:74], urbanhour6[70:74], urbanhour7[70:74], urbanhour8[70:74], urbanhour9[70:74], urbanhour10[70:74], urbanhour11[70:74], urbanhour12[70:74], urbanhour13[70:74], urbanhour14[70:74], urbanhour15[70:74], urbanhour16[70:74], urbanhour17[70:74], urbanhour18[70:74], urbanhour19[70:74], urbanhour20[70:74], urbanhour21[70:74], urbanhour22[70:74], urbanhour23[70:74]]
suburbansHW5 = [suburbanhour00[70:74], suburbanhour1[70:74], suburbanhour2[70:74], suburbanhour3[70:74], suburbanhour4[70:74], suburbanhour5[70:74], suburbanhour6[70:74], suburbanhour7[70:74], suburbanhour8[70:74], suburbanhour9[70:74], suburbanhour10[70:74], suburbanhour11[70:74], suburbanhour12[70:74], suburbanhour13[70:74], suburbanhour14[70:74], suburbanhour15[70:74], suburbanhour16[70:74], suburbanhour17[70:74], suburbanhour18[70:74], suburbanhour19[70:74], suburbanhour20[70:74], suburbanhour21[70:74], suburbanhour22[70:74], suburbanhour23[70:74]]
ruralsHW5 = [ruralhour00[70:74], ruralhour1[70:74], ruralhour2[70:74], ruralhour3[70:74], ruralhour4[70:74], ruralhour5[70:74], ruralhour6[70:74], ruralhour7[70:74], ruralhour8[70:74], ruralhour9[70:74], ruralhour10[70:74], ruralhour11[70:74], ruralhour12[70:74], ruralhour13[70:74], ruralhour14[70:74], ruralhour15[70:74], ruralhour16[70:74], ruralhour17[70:74], ruralhour18[70:74], ruralhour19[70:74], ruralhour20[70:74], ruralhour21[70:74], ruralhour22[70:74], ruralhour23[70:74]]

# Coolwave 6 [76:84]
urbansHW6 = [urbanhour00[76:84], urbanhour1[76:84], urbanhour2[76:84], urbanhour3[76:84], urbanhour4[76:84], urbanhour5[76:84], urbanhour6[76:84], urbanhour7[76:84], urbanhour8[76:84], urbanhour9[76:84], urbanhour10[76:84], urbanhour11[76:84], urbanhour12[76:84], urbanhour13[76:84], urbanhour14[76:84], urbanhour15[76:84], urbanhour16[76:84], urbanhour17[76:84], urbanhour18[76:84], urbanhour19[76:84], urbanhour20[76:84], urbanhour21[76:84], urbanhour22[76:84], urbanhour23[76:84]]
suburbansHW6 = [suburbanhour00[76:84], suburbanhour1[76:84], suburbanhour2[76:84], suburbanhour3[76:84], suburbanhour4[76:84], suburbanhour5[76:84], suburbanhour6[76:84], suburbanhour7[76:84], suburbanhour8[76:84], suburbanhour9[76:84], suburbanhour10[76:84], suburbanhour11[76:84], suburbanhour12[76:84], suburbanhour13[76:84], suburbanhour14[76:84], suburbanhour15[76:84], suburbanhour16[76:84], suburbanhour17[76:84], suburbanhour18[76:84], suburbanhour19[76:84], suburbanhour20[76:84], suburbanhour21[76:84], suburbanhour22[76:84], suburbanhour23[76:84]]
ruralsHW6 = [ruralhour00[76:84], ruralhour1[76:84], ruralhour2[76:84], ruralhour3[76:84], ruralhour4[76:84], ruralhour5[76:84], ruralhour6[76:84], ruralhour7[76:84], ruralhour8[76:84], ruralhour9[76:84], ruralhour10[76:84], ruralhour11[76:84], ruralhour12[76:84], ruralhour13[76:84], ruralhour14[76:84], ruralhour15[76:84], ruralhour16[76:84], ruralhour17[76:84], ruralhour18[76:84], ruralhour19[76:84], ruralhour20[76:84], ruralhour21[76:84], ruralhour22[76:84], ruralhour23[76:84]]

# %%
differenceHW1urban = []
differenceHW1suburban = []
differenceHW1rural = []

differenceHW2urban = []
differenceHW2suburban = []
differenceHW2rural = []

differenceHW3urban = []
differenceHW3suburban = []
differenceHW3rural = []

differenceHW4urban = []
differenceHW4suburban = []
differenceHW4rural = []

differenceHW5urban = []
differenceHW5suburban = []
differenceHW5rural = []

differenceHW6urban = []
differenceHW6suburban = []
differenceHW6rural = []
# Loop over each hour (assuming 24 hours)
for i in range(0, 24):
    # Heatwave 1 (range 0-9)
    differenceHW1urban.append(fcst12urbanHW1[i] - urbansHW1[i])
    differenceHW1suburban.append(fcst12suburbanHW1[i] - suburbansHW1[i])
    differenceHW1rural.append(fcst12ruralHW1[i] - ruralsHW1[i])
    
    # Heatwave 2 (range 10-19)
    differenceHW2urban.append(fcst12urbanHW2[i] - urbansHW2[i])
    differenceHW2suburban.append(fcst12suburbanHW2[i] - suburbansHW2[i])
    differenceHW2rural.append(fcst12ruralHW2[i] - ruralsHW2[i])
    
    # Heatwave 3 (range 20-29)
    differenceHW3urban.append(fcst12urbanHW3[i] - urbansHW3[i])
    differenceHW3suburban.append(fcst12suburbanHW3[i] - suburbansHW3[i])
    differenceHW3rural.append(fcst12ruralHW3[i] - ruralsHW3[i])
    
    # Heatwave 4 (range 30-39)
    differenceHW4urban.append(fcst12urbanHW4[i] - urbansHW4[i])
    differenceHW4suburban.append(fcst12suburbanHW4[i] - suburbansHW4[i])
    differenceHW4rural.append(fcst12ruralHW4[i] - ruralsHW4[i])
    
    # Heatwave 5 (range 40-49)
    #differenceHW5urban.append(fcst12urbanHW5[i] - urbansHW5[i])
    #differenceHW5suburban.append(fcst12suburbanHW5[i] - suburbansHW5[i])
    #differenceHW5rural.append(fcst12ruralHW5[i] - ruralsHW5[i])
    
    # Heatwave 6 (range 65-74)
    differenceHW6urban.append(fcst12urbanHW6[i] - urbansHW6[i])
    differenceHW6suburban.append(fcst12suburbanHW6[i] - suburbansHW6[i])
    differenceHW6rural.append(fcst12ruralHW6[i] - ruralsHW6[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-77f19e91e956> in <module>
#      50
#      51     # Heatwave 6 (range 65-74)
# ---> 52     differenceHW6urban.append(fcst12urbanHW6[i] - urbansHW6[i])
#      53     differenceHW6suburban.append(fcst12suburbanHW6[i] - suburbansHW6[i])
#      54     differenceHW6rural.append(fcst12ruralHW6[i] - ruralsHW6[i])
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __sub__(self, other)
#      95     @unpack_zerodim_and_defer("__sub__")
#      96     def __sub__(self, other):
# ---> 97         return self._arith_method(other, operator.sub)
#      98
# ...

# %%
import math
listHW1urban=[]
listHW1suburban=[]
listHW1rural=[]

listHW2urban=[]
listHW2suburban=[]
listHW2rural=[]

listHW3urban=[]
listHW3suburban=[]
listHW3rural=[]

listHW4urban=[]
listHW4suburban=[]
listHW4rural=[]

listHW6urban=[]
listHW6suburban=[]
listHW6rural=[]
for i in range(0,24):
    cleaned_list1 = [x for x in differenceHW1urban[i] if not math.isnan(x)]
    cleaned_list2 = [x for x in differenceHW1suburban[i] if not math.isnan(x)]
    cleaned_list3 = [x for x in differenceHW1rural[i] if not math.isnan(x)]
    
    cleaned_list4 = [x for x in differenceHW2urban[i] if not math.isnan(x)]
    cleaned_list5 = [x for x in differenceHW2suburban[i] if not math.isnan(x)]
    cleaned_list6 = [x for x in differenceHW2rural[i] if not math.isnan(x)]
    
    cleaned_list7 = [x for x in differenceHW3urban[i] if not math.isnan(x)]
    cleaned_list8 = [x for x in differenceHW3suburban[i] if not math.isnan(x)]
    cleaned_list9 = [x for x in differenceHW3rural[i] if not math.isnan(x)]
    
    cleaned_list10 = [x for x in differenceHW4urban[i] if not math.isnan(x)]
    cleaned_list11 = [x for x in differenceHW4suburban[i] if not math.isnan(x)]
    cleaned_list12 = [x for x in differenceHW4rural[i] if not math.isnan(x)]
    
    #cleaned_list13 = [x for x in differenceHW6urban[i] if not math.isnan(x)]
    #cleaned_list14 = [x for x in differenceHW6suburban[i] if not math.isnan(x)]
    #cleaned_list15 = [x for x in differenceHW6rural[i] if not math.isnan(x)]
    
    listHW1urban.append(cleaned_list1)
    listHW1suburban.append(cleaned_list2)
    listHW1rural.append(cleaned_list3)
    
    listHW2urban.append(cleaned_list4)
    listHW2suburban.append(cleaned_list5)
    listHW2rural.append(cleaned_list6)
    
    listHW3urban.append(cleaned_list7)
    listHW3suburban.append(cleaned_list8)
    listHW3rural.append(cleaned_list9)
    
    listHW4urban.append(cleaned_list10)
    listHW4suburban.append(cleaned_list11)
    listHW4rural.append(cleaned_list12)
    
    #listHW6urban.append(cleaned_list13)
    #listHW6suburban.append(cleaned_list14)
    #listHW6rural.append(cleaned_list15)

# %%
import numpy as np

# Lists for storing averages
averageUrban = []
averageSuburban = []
averageRural = []

# Loop through each heatwave
for i in range(0, 24):
    for ii in range(0,1):
        # Create a list of the differences for each location and heatwave for the current time step
        urban_differences=(listHW1urban[i]+listHW2urban[i]+listHW3urban[i]+listHW4urban[i])
        averageUrban.append(urban_differences)
        suburban_differences=(listHW1suburban[i]+listHW2suburban[i]+listHW3suburban[i]+listHW4suburban[i])
        averageSuburban.append(suburban_differences)
        rural_differences=(listHW1rural[i]+listHW2rural[i]+listHW3rural[i]+listHW4rural[i])
        averageRural.append(rural_differences)
    # Calculate the average, ignoring NaN values

# %%
fig, axes = plt.subplots(3, 1, figsize=(7, 10))  # 3 rows, 1 column

axes[0].boxplot(averageUrban)
axes[0].set_title('Urban - 12')
#axes[0].set_ylim(-15,15)
axes[0].set_xlabel('Times (UTC)')
axes[0].set_ylabel('Humidity (%) (model-observations)')

axes[1].boxplot(averageSuburban)
#axes[1].set_ylim(-15,15)
axes[1].set_title('Suburban - 12')
axes[1].set_xlabel('Times (UTC)')
axes[1].set_ylabel('Humidity (%) (model-observations)')

axes[2].boxplot(averageRural)
#axes[2].set_ylim(-15,15)
axes[2].set_title('Rural - 12')
axes[2].set_xlabel('Time (UTC)')
axes[2].set_ylabel('Humidity (%) (model-observations)')

axes[0].axhline(y=0,ls='--',color='red')
axes[1].axhline(y=0,ls='--',color='red')
axes[2].axhline(y=0,ls='--',color='red')

plt.tight_layout()
plt.savefig('CoolwaveBoxplots12RH.png', dpi=1200)
plt.show()

# %%
total=[np.average(averageUrban[0])-np.average(averageRural[0]),np.average(averageUrban[1])-np.average(averageRural[1]),np.average(averageUrban[2])-np.average(averageRural[2]),np.average(averageUrban[3])-np.average(averageRural[3])]
print('uhi',np.average(total))
# Out:
# uhi -6.81251455549199
