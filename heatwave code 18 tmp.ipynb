# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#load model data
hrrrtmp18=pd.read_csv(r"C:\Users\sierra\Downloads\thrrrTMP18.csv")

# %%
#adds a datetime index to the pandas dataframe
timeindex = pd.date_range(start='2024-06-01-18',end='2024-09-01-17', freq='H')
hrrrtmp18.index=timeindex

# %%
fcst18hour00=hrrrtmp18.at_time('00:00:00')
fcst18hour01=hrrrtmp18.at_time('1:00:00')
fcst18hour02=hrrrtmp18.at_time('2:00:00')
fcst18hour03=hrrrtmp18.at_time('3:00:00')
fcst18hour04=hrrrtmp18.at_time('4:00:00')
fcst18hour05=hrrrtmp18.at_time('5:00:00')
fcst18hour06=hrrrtmp18.at_time('6:00:00')
fcst18hour07=hrrrtmp18.at_time('7:00:00')
fcst18hour08=hrrrtmp18.at_time('8:00:00')
fcst18hour09=hrrrtmp18.at_time('9:00:00')
fcst18hour10=hrrrtmp18.at_time('10:00:00')
fcst18hour11=hrrrtmp18.at_time('11:00:00')
fcst18hour12=hrrrtmp18.at_time('12:00:00')
fcst18hour13=hrrrtmp18.at_time('13:00:00')
fcst18hour14=hrrrtmp18.at_time('14:00:00')
fcst18hour15=hrrrtmp18.at_time('15:00:00')
fcst18hour16=hrrrtmp18.at_time('16:00:00')
fcst18hour17=hrrrtmp18.at_time('17:00:00')
fcst18hour18=hrrrtmp18.at_time('18:00:00')
fcst18hour19=hrrrtmp18.at_time('19:00:00')
fcst18hour20=hrrrtmp18.at_time('20:00:00')
fcst18hour21=hrrrtmp18.at_time('21:00:00')
fcst18hour22=hrrrtmp18.at_time('22:00:00')
fcst18hour23=hrrrtmp18.at_time('23:00:00')

# %%
fcst18hour00urban = (fcst18hour00['0'] + fcst18hour00['1'] + fcst18hour00['2'] + fcst18hour00['4'] + fcst18hour00['9'] + fcst18hour00['10'] + fcst18hour00['13'] + fcst18hour00['14']) / 8
fcst18hour01urban = (fcst18hour01['0'] + fcst18hour01['1'] + fcst18hour01['2'] + fcst18hour01['4'] + fcst18hour01['9'] + fcst18hour01['10'] + fcst18hour01['13'] + fcst18hour01['14']) / 8
fcst18hour02urban = (fcst18hour02['0'] + fcst18hour02['1'] + fcst18hour02['2'] + fcst18hour02['4'] + fcst18hour02['9'] + fcst18hour02['10'] + fcst18hour02['13'] + fcst18hour02['14']) / 8
fcst18hour03urban = (fcst18hour03['0'] + fcst18hour03['1'] + fcst18hour03['2'] + fcst18hour03['4'] + fcst18hour03['9'] + fcst18hour03['10'] + fcst18hour03['13'] + fcst18hour03['14']) / 8
fcst18hour04urban = (fcst18hour04['0'] + fcst18hour04['1'] + fcst18hour04['2'] + fcst18hour04['4'] + fcst18hour04['9'] + fcst18hour04['10'] + fcst18hour04['13'] + fcst18hour04['14']) / 8
fcst18hour05urban = (fcst18hour05['0'] + fcst18hour05['1'] + fcst18hour05['2'] + fcst18hour05['4'] + fcst18hour05['9'] + fcst18hour05['10'] + fcst18hour05['13'] + fcst18hour05['14']) / 8
fcst18hour06urban = (fcst18hour06['0'] + fcst18hour06['1'] + fcst18hour06['2'] + fcst18hour06['4'] + fcst18hour06['9'] + fcst18hour06['10'] + fcst18hour06['13'] + fcst18hour06['14']) / 8
fcst18hour07urban = (fcst18hour07['0'] + fcst18hour07['1'] + fcst18hour07['2'] + fcst18hour07['4'] + fcst18hour07['9'] + fcst18hour07['10'] + fcst18hour07['13'] + fcst18hour07['14']) / 8
fcst18hour08urban = (fcst18hour08['0'] + fcst18hour08['1'] + fcst18hour08['2'] + fcst18hour08['4'] + fcst18hour08['9'] + fcst18hour08['10'] + fcst18hour08['13'] + fcst18hour08['14']) / 8
fcst18hour09urban = (fcst18hour09['0'] + fcst18hour09['1'] + fcst18hour09['2'] + fcst18hour09['4'] + fcst18hour09['9'] + fcst18hour09['10'] + fcst18hour09['13'] + fcst18hour09['14']) / 8
fcst18hour10urban = (fcst18hour10['0'] + fcst18hour10['1'] + fcst18hour10['2'] + fcst18hour10['4'] + fcst18hour10['9'] + fcst18hour10['10'] + fcst18hour10['13'] + fcst18hour10['14']) / 8
fcst18hour11urban = (fcst18hour11['0'] + fcst18hour11['1'] + fcst18hour11['2'] + fcst18hour11['4'] + fcst18hour11['9'] + fcst18hour11['10'] + fcst18hour11['13'] + fcst18hour11['14']) / 8
fcst18hour12urban = (fcst18hour12['0'] + fcst18hour12['1'] + fcst18hour12['2'] + fcst18hour12['4'] + fcst18hour12['9'] + fcst18hour12['10'] + fcst18hour12['13'] + fcst18hour12['14']) / 8
fcst18hour13urban = (fcst18hour13['0'] + fcst18hour13['1'] + fcst18hour13['2'] + fcst18hour13['4'] + fcst18hour13['9'] + fcst18hour13['10'] + fcst18hour13['13'] + fcst18hour13['14']) / 8
fcst18hour14urban = (fcst18hour14['0'] + fcst18hour14['1'] + fcst18hour14['2'] + fcst18hour14['4'] + fcst18hour14['9'] + fcst18hour14['10'] + fcst18hour14['13'] + fcst18hour14['14']) / 8
fcst18hour15urban = (fcst18hour15['0'] + fcst18hour15['1'] + fcst18hour15['2'] + fcst18hour15['4'] + fcst18hour15['9'] + fcst18hour15['10'] + fcst18hour15['13'] + fcst18hour15['14']) / 8
fcst18hour16urban = (fcst18hour16['0'] + fcst18hour16['1'] + fcst18hour16['2'] + fcst18hour16['4'] + fcst18hour16['9'] + fcst18hour16['10'] + fcst18hour16['13'] + fcst18hour16['14']) / 8
fcst18hour17urban = (fcst18hour17['0'] + fcst18hour17['1'] + fcst18hour17['2'] + fcst18hour17['4'] + fcst18hour17['9'] + fcst18hour17['10'] + fcst18hour17['13'] + fcst18hour17['14']) / 8
fcst18hour18urban = (fcst18hour18['0'] + fcst18hour18['1'] + fcst18hour18['2'] + fcst18hour18['4'] + fcst18hour18['9'] + fcst18hour18['10'] + fcst18hour18['13'] + fcst18hour18['14']) / 8
fcst18hour19urban = (fcst18hour19['0'] + fcst18hour19['1'] + fcst18hour19['2'] + fcst18hour19['4'] + fcst18hour19['9'] + fcst18hour19['10'] + fcst18hour19['13'] + fcst18hour19['14']) / 8
fcst18hour20urban = (fcst18hour20['0'] + fcst18hour20['1'] + fcst18hour20['2'] + fcst18hour20['4'] + fcst18hour20['9'] + fcst18hour20['10'] + fcst18hour20['13'] + fcst18hour20['14']) / 8
fcst18hour21urban = (fcst18hour21['0'] + fcst18hour21['1'] + fcst18hour21['2'] + fcst18hour21['4'] + fcst18hour21['9'] + fcst18hour21['10'] + fcst18hour21['13'] + fcst18hour21['14']) / 8
fcst18hour22urban = (fcst18hour22['0'] + fcst18hour22['1'] + fcst18hour22['2'] + fcst18hour22['4'] + fcst18hour22['9'] + fcst18hour22['10'] + fcst18hour22['13'] + fcst18hour22['14']) / 8
fcst18hour23urban = (fcst18hour23['0'] + fcst18hour23['1'] + fcst18hour23['2'] + fcst18hour23['4'] + fcst18hour23['9'] + fcst18hour23['10'] + fcst18hour23['13'] + fcst18hour23['14']) / 8

# %%
fcst18hour00suburban = (fcst18hour00['15'] + fcst18hour00['6'] + fcst18hour00['9'] + fcst18hour00['11'] + fcst18hour00['12']) / 5
fcst18hour01suburban = (fcst18hour01['15'] + fcst18hour01['6'] + fcst18hour01['9'] + fcst18hour01['11'] + fcst18hour01['12']) / 5
fcst18hour02suburban = (fcst18hour02['15'] + fcst18hour02['6'] + fcst18hour02['9'] + fcst18hour02['11'] + fcst18hour02['12']) / 5
fcst18hour03suburban = (fcst18hour03['15'] + fcst18hour03['6'] + fcst18hour03['9'] + fcst18hour03['11'] + fcst18hour03['12']) / 5
fcst18hour04suburban = (fcst18hour04['15'] + fcst18hour04['6'] + fcst18hour04['9'] + fcst18hour04['11'] + fcst18hour04['12']) / 5
fcst18hour05suburban = (fcst18hour05['15'] + fcst18hour05['6'] + fcst18hour05['9'] + fcst18hour05['11'] + fcst18hour05['12']) / 5
fcst18hour06suburban = (fcst18hour06['15'] + fcst18hour06['6'] + fcst18hour06['9'] + fcst18hour06['11'] + fcst18hour06['12']) / 5
fcst18hour07suburban = (fcst18hour07['15'] + fcst18hour07['6'] + fcst18hour07['9'] + fcst18hour07['11'] + fcst18hour07['12']) / 5
fcst18hour08suburban = (fcst18hour08['15'] + fcst18hour08['6'] + fcst18hour08['9'] + fcst18hour08['11'] + fcst18hour08['12']) / 5
fcst18hour09suburban = (fcst18hour09['15'] + fcst18hour09['6'] + fcst18hour09['9'] + fcst18hour09['11'] + fcst18hour09['12']) / 5
fcst18hour10suburban = (fcst18hour10['15'] + fcst18hour10['6'] + fcst18hour10['9'] + fcst18hour10['11'] + fcst18hour10['12']) / 5
fcst18hour11suburban = (fcst18hour11['15'] + fcst18hour11['6'] + fcst18hour11['9'] + fcst18hour11['11'] + fcst18hour11['12']) / 5
fcst18hour12suburban = (fcst18hour12['15'] + fcst18hour12['6'] + fcst18hour12['9'] + fcst18hour12['11'] + fcst18hour12['12']) / 5
fcst18hour13suburban = (fcst18hour13['15'] + fcst18hour13['6'] + fcst18hour13['9'] + fcst18hour13['11'] + fcst18hour13['12']) / 5
fcst18hour14suburban = (fcst18hour14['15'] + fcst18hour14['6'] + fcst18hour14['9'] + fcst18hour14['11'] + fcst18hour14['12']) / 5
fcst18hour15suburban = (fcst18hour15['15'] + fcst18hour15['6'] + fcst18hour15['9'] + fcst18hour15['11'] + fcst18hour15['12']) / 5
fcst18hour16suburban = (fcst18hour16['15'] + fcst18hour16['6'] + fcst18hour16['9'] + fcst18hour16['11'] + fcst18hour16['12']) / 5
fcst18hour17suburban = (fcst18hour17['15'] + fcst18hour17['6'] + fcst18hour17['9'] + fcst18hour17['11'] + fcst18hour17['12']) / 5
fcst18hour18suburban = (fcst18hour18['15'] + fcst18hour18['6'] + fcst18hour18['9'] + fcst18hour18['11'] + fcst18hour18['12']) / 5
fcst18hour19suburban = (fcst18hour19['15'] + fcst18hour19['6'] + fcst18hour19['9'] + fcst18hour19['11'] + fcst18hour19['12']) / 5
fcst18hour20suburban = (fcst18hour20['15'] + fcst18hour20['6'] + fcst18hour20['9'] + fcst18hour20['11'] + fcst18hour20['12']) / 5
fcst18hour21suburban = (fcst18hour21['15'] + fcst18hour21['6'] + fcst18hour21['9'] + fcst18hour21['11'] + fcst18hour21['12']) / 5
fcst18hour22suburban = (fcst18hour22['15'] + fcst18hour22['6'] + fcst18hour22['9'] + fcst18hour22['11'] + fcst18hour22['12']) / 5
fcst18hour23suburban = (fcst18hour23['15'] + fcst18hour23['6'] + fcst18hour23['9'] + fcst18hour23['11'] + fcst18hour23['12']) / 5

# %%
fcst18hour00rural = (fcst18hour00['4'] + fcst18hour00['5'] + fcst18hour00['8']) / 3
fcst18hour01rural = (fcst18hour01['4'] + fcst18hour01['5'] + fcst18hour01['8']) / 3
fcst18hour02rural = (fcst18hour02['4'] + fcst18hour02['5'] + fcst18hour02['8']) / 3
fcst18hour03rural = (fcst18hour03['4'] + fcst18hour03['5'] + fcst18hour03['8']) / 3
fcst18hour04rural = (fcst18hour04['4'] + fcst18hour04['5'] + fcst18hour04['8']) / 3
fcst18hour05rural = (fcst18hour05['4'] + fcst18hour05['5'] + fcst18hour05['8']) / 3
fcst18hour06rural = (fcst18hour06['4'] + fcst18hour06['5'] + fcst18hour06['8']) / 3
fcst18hour07rural = (fcst18hour07['4'] + fcst18hour07['5'] + fcst18hour07['8']) / 3
fcst18hour08rural = (fcst18hour08['4'] + fcst18hour08['5'] + fcst18hour08['8']) / 3
fcst18hour09rural = (fcst18hour09['4'] + fcst18hour09['5'] + fcst18hour09['8']) / 3
fcst18hour10rural = (fcst18hour10['4'] + fcst18hour10['5'] + fcst18hour10['8']) / 3
fcst18hour11rural = (fcst18hour11['4'] + fcst18hour11['5'] + fcst18hour11['8']) / 3
fcst18hour12rural = (fcst18hour12['4'] + fcst18hour12['5'] + fcst18hour12['8']) / 3
fcst18hour13rural = (fcst18hour13['4'] + fcst18hour13['5'] + fcst18hour13['8']) / 3
fcst18hour14rural = (fcst18hour14['4'] + fcst18hour14['5'] + fcst18hour14['8']) / 3
fcst18hour15rural = (fcst18hour15['4'] + fcst18hour15['5'] + fcst18hour15['8']) / 3
fcst18hour16rural = (fcst18hour16['4'] + fcst18hour16['5'] + fcst18hour16['8']) / 3
fcst18hour17rural = (fcst18hour17['4'] + fcst18hour17['5'] + fcst18hour17['8']) / 3
fcst18hour18rural = (fcst18hour18['4'] + fcst18hour18['5'] + fcst18hour18['8']) / 3
fcst18hour19rural = (fcst18hour19['4'] + fcst18hour19['5'] + fcst18hour19['8']) / 3
fcst18hour20rural = (fcst18hour20['4'] + fcst18hour20['5'] + fcst18hour20['8']) / 3
fcst18hour21rural = (fcst18hour21['4'] + fcst18hour21['5'] + fcst18hour21['8']) / 3
fcst18hour22rural = (fcst18hour22['4'] + fcst18hour22['5'] + fcst18hour22['8']) / 3
fcst18hour23rural = (fcst18hour23['4'] + fcst18hour23['5'] + fcst18hour23['8']) / 3

# %%
#DO NOT RUN MORE THAN ONCE IN SCRIPT  TEMPERATURE
df=pd.read_csv(r"C:\Users\sierra\Downloads\Mesonet_Hill.csv")
clarksville=[]
baltimore=[]
for ii in range(0,7222):
    if df['station_name'][ii] == 'Clarksville':
        clarksville.append(ii)
    if df['station_name'][ii] == 'Baltimore':
        baltimore.append(ii)
clarksvilleTMP=df['Air_Temperature_2m_Avg_C'][0:clarksville[-1]-4]
baltimoreTMP=df['Air_Temperature_2m_Avg_C'][baltimore[0]:baltimore[-1]-4]

timeindex = pd.date_range(start='2024-06-01-18:00:00',end='2024-08-31-23', freq='H')
clarksvilleTMP=clarksvilleTMP[14:]
clarksvilleTMP.index=timeindex
baltimoreTMP=baltimoreTMP[14:]
baltimoreTMP.index=timeindex

dayClarkTMP=clarksvilleTMP.between_time('10:00:00','00:00:00')
nightClarkTMP=clarksvilleTMP.between_time('1:00:00','9:00:00')
dayBaltTMP=baltimoreTMP.between_time('10:00:00','00:00:00')
nightBaltTMP=baltimoreTMP.between_time('1:00:00','9:00:00')

# %%
#Load obs data for all working stations in the BSEC project
AAC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-AAC_AWS_hourly_average.csv")
AAC_AWS=AAC_AWS[18:]
timeindex = pd.date_range(start='2024-06-01-18:00:00',end='2024-08-31-23', freq='H')
AAC_AWS.index=timeindex
dayaac=AAC_AWS.between_time('10:00:00','00:00:00')
nightaac=AAC_AWS.between_time('1:00:00','9:00:00')

ABL_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-ABL_AWS_hourly_average.csv")
ABL_AWS=ABL_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
ABL_AWS.index=timeindex
dayabl=ABL_AWS.between_time('10:00:00','00:00:00')
nightabl=ABL_AWS.between_time('1:00:00','9:00:00')

AGC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-AGC_AWS_hourly_average.csv")
AGC_AWS=AGC_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
AGC_AWS.index=timeindex
dayagc=AGC_AWS.between_time('10:00:00','00:00:00')
nightagc=AGC_AWS.between_time('1:00:00','9:00:00')

ARK2_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-ARK2_OTT_hourly_average.csv")
ARK2_OTT=ARK2_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
ARK2_OTT.index=timeindex
dayark2=ARK2_OTT.between_time('10:00:00','00:00:00')
nightark2=ARK2_OTT.between_time('1:00:00','9:00:00')

BCC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-BCC_AWS_hourly_average.csv")
BCC_AWS=BCC_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
BCC_AWS.index=timeindex
daybcc=BCC_AWS.between_time('10:00:00','00:00:00')
nightbcc=BCC_AWS.between_time('1:00:00','9:00:00')

CARE_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CARE_OTT_hourly_average.csv")
CARE_OTT=CARE_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
CARE_OTT.index=timeindex
daycare=CARE_OTT.between_time('10:00:00','00:00:00')
nightcare=CARE_OTT.between_time('1:00:00','9:00:00')

CLV_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CLV_AWS_hourly_average.csv")
CLV_AWS=CLV_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
CLV_AWS.index=timeindex
dayclv=CLV_AWS.between_time('10:00:00','00:00:00')
nightclv=CLV_AWS.between_time('1:00:00','9:00:00')

CLV2_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CLV2_AWS_hourly_average.csv")
CLV2_AWS=CLV2_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
CLV2_AWS.index=timeindex
dayclv2=CLV2_AWS.between_time('10:00:00','00:00:00')
nightclv2=CLV2_AWS.between_time('1:00:00','9:00:00')

COV_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-COV_AWS_hourly_average.csv")
COV_AWS=COV_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
COV_AWS.index=timeindex
daycov=COV_AWS.between_time('10:00:00','00:00:00')
nightcov=COV_AWS.between_time('1:00:00','9:00:00')

COV2_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-COV2_AWS_hourly_average.csv")
COV2_AWS=COV2_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
COV2_AWS.index=timeindex
daycov2aws=COV2_AWS.between_time('10:00:00','00:00:00')
nightcov2aws=COV2_AWS.between_time('1:00:00','9:00:00')

COV2_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-COV2_OTT_hourly_average.csv")
COV2_OTT=COV2_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
COV2_OTT.index=timeindex
daycov2ott=COV2_OTT.between_time('10:00:00','00:00:00')
nightcov2ott=COV2_OTT.between_time('1:00:00','9:00:00')

DSG_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-DSG_OTT_hourly_average (2).csv")
DSG_OTT=DSG_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
DSG_OTT.index=timeindex
daydsg=DSG_OTT.between_time('10:00:00','00:00:00')
nightdsg=DSG_OTT.between_time('1:00:00','9:00:00')

FSG_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-FSG_OTT_hourly_average.csv")
FSG_OTT=FSG_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
FSG_OTT.index=timeindex
dayfsg=FSG_OTT.between_time('10:00:00','00:00:00')
nightfsg=FSG_OTT.between_time('1:00:00','9:00:00')

GKF_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-GKF_AWS_hourly_average.csv")
GKF_AWS=GKF_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
GKF_AWS.index=timeindex
daygkf=GKF_AWS.between_time('10:00:00','00:00:00')
nightgkf=GKF_AWS.between_time('1:00:00','9:00:00')

GSA_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-GSA_AWS_hourly_average.csv")
GSA_AWS=GSA_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
GSA_AWS.index=timeindex
daygsa=GSA_AWS.between_time('10:00:00','00:00:00')
nightgsa=GSA_AWS.between_time('1:00:00','9:00:00')

JHU_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-JHU_AWS_hourly_average.csv")
JHU_AWS=JHU_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
JHU_AWS.index=timeindex
dayjhu=JHU_AWS.between_time('10:00:00','00:00:00')
nightjhu=JHU_AWS.between_time('1:00:00','9:00:00')

LGC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-LGC_AWS_hourly_average.csv")
LGC_AWS=LGC_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
LGC_AWS.index=timeindex
daylgc=LGC_AWS.between_time('10:00:00','00:00:00')
nightlgc=LGC_AWS.between_time('1:00:00','9:00:00')

LRT_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-LRT_OTT_hourly_average.csv")
LRT_OTT=LRT_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
LRT_OTT.index=timeindex
daylrt=LRT_OTT.between_time('10:00:00','00:00:00')
nightlrt=LRT_OTT.between_time('1:00:00','9:00:00')


MSU_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-MSU_OTT_hourly_average.csv")
MSU_OTT=MSU_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
MSU_OTT.index=timeindex
daymsu=MSU_OTT.between_time('10:00:00','00:00:00')
nightmsu=MSU_OTT.between_time('1:00:00','9:00:00')

MCN_OTT=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-CMN_OTT_hourly_2024.csv")
MCN_OTT=MCN_OTT[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
MCN_OTT.index=timeindex
daymcn=MCN_OTT.between_time('10:00:00','00:00:00')
nightmcn=MCN_OTT.between_time('1:00:00','9:00:00')

NRP_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-NRP_AWS_hourly_average.csv")
NRP_AWS=NRP_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
NRP_AWS.index=timeindex
daynrp=NRP_AWS.between_time('10:00:00','00:00:00')
nightnrp=NRP_AWS.between_time('1:00:00','9:00:00')

OG_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-OG_AWS_hourly_average.csv")
OG_AWS=OG_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
OG_AWS.index=timeindex
dayog=OG_AWS.between_time('10:00:00','00:00:00')
nightog=OG_AWS.between_time('1:00:00','9:00:00')

SHC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-SHC_AWS_hourly_average.csv")
SHC_AWS=SHC_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
SHC_AWS.index=timeindex
dayshc=SHC_AWS.between_time('10:00:00','00:00:00')
nightshc=SHC_AWS.between_time('1:00:00','9:00:00')

SMF_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-SMF_AWS_hourly_average.csv")
SMF_AWS=SMF_AWS[18:]
#timeindex = pd.date_range(start='2024-06-01-0:00:00',end='2024-08-31-05', freq='H')
SMF_AWS.index=timeindex
daysmf=SMF_AWS.between_time('10:00:00','00:00:00')
nightsmf=SMF_AWS.between_time('1:00:00','9:00:00')

UBC_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-UBC_AWS_hourly_average.csv")
UBC_AWS=UBC_AWS[18:]
timeindex = pd.date_range(start='2024-06-01-18:00:00',end='2024-09-01-00', freq='H')
UBC_AWS.index=timeindex
dayubc=UBC_AWS.between_time('10:00:00','00:00:00')
nightubc=UBC_AWS.between_time('1:00:00','9:00:00')

WHE_AWS=pd.read_csv(r"C:\Users\sierra\Downloads\BSEC-WHE_AWS_hourly_average.csv")
WHE_AWS=WHE_AWS[18:]
timeindex = pd.date_range(start='2024-06-01-18:00:00',end='2024-09-01-00', freq='H')
WHE_AWS.index=timeindex
daywhe=WHE_AWS.between_time('10:00:00','00:00:00')
nightwhe=WHE_AWS.between_time('1:00:00','9:00:00')

# %%
dayaac=dayaac['tempAvg']
dayabl=dayabl['tempAvg']
dayagc=dayagc['tempAvg']
dayark2=dayark2['tempAvg']
daybcc=daybcc['tempAvg']
daycare=daycare['tempAvg']
dayclv=dayclv['tempAvg']
dayclv2=dayclv2['tempAvg']
daycov=daycov['tempAvg']
daycov2aws=daycov2aws['tempAvg']
daycov2ott=daycov2ott['tempAvg']
daydsg=daydsg['tempAvg']
dayfsg=dayfsg['tempAvg']
daygkf=daygkf['tempAvg']
daygsa=daygsa['tempAvg']
dayjhu=dayjhu['tempAvg']
daylgc=daylgc['tempAvg']
daylrt=daylrt['tempAvg']
daymsu=daymsu['tempAvg']
daymcn=daymcn['tempAvg']
daynrp=daynrp['tempAvg']
dayog=dayog['tempAvg']
dayshc=dayshc['tempAvg']
daysmf=daysmf['tempAvg']
dayubc=dayubc['tempAvg']
daywhe=daywhe['tempAvg']

nightaac=nightaac['tempAvg']
nightabl=nightabl['tempAvg']
nightagc=nightagc['tempAvg']
nightark2=nightark2['tempAvg']
nightbcc=nightbcc['tempAvg']
nightcare=nightcare['tempAvg']
nightclv=nightclv['tempAvg']
nightclv2=nightclv2['tempAvg']
nightcov=nightcov['tempAvg']
nightcov2aws=nightcov2aws['tempAvg']
nightcov2ott=nightcov2ott['tempAvg']
nightdsg=nightdsg['tempAvg']
nightfsg=nightfsg['tempAvg']
nightgkf=nightgkf['tempAvg']
nightgsa=nightgsa['tempAvg']
nightjhu=nightjhu['tempAvg']
nightlgc=nightlgc['tempAvg']
nightlrt=nightlrt['tempAvg']
nightmsu=nightmsu['tempAvg']
nightmcn=nightmcn['tempAvg']
nightnrp=nightnrp['tempAvg']
nightog=nightog['tempAvg']
nightshc=nightshc['tempAvg']
nightsmf=nightsmf['tempAvg']
nightubc=nightubc['tempAvg']
nightwhe=nightwhe['tempAvg']

# %%
station_list_day=[dayaac,dayabl,dayagc,dayark2,daybcc,daycare,dayclv,dayclv2,daycov,daycov2aws,daycov2ott,daydsg,dayfsg,daygkf,daygsa,dayjhu,daylgc,daymsu,daymcn,daynrp,dayog,dayshc,daysmf,daywhe,dayClarkTMP]
station_list_night=[nightaac,nightabl,nightagc,nightark2,nightbcc,nightcare,nightclv,nightclv2,nightcov,nightcov2aws,nightcov2ott,nightdsg,nightfsg,nightgkf,nightgsa,nightjhu,nightlgc,nightmsu,nightmcn,nightnrp,nightog,nightshc,nightsmf,nightwhe,nightClarkTMP]

# %%
hour1=[]
hour2=[]
hour3=[]
hour4=[]
hour5=[]
hour6=[]
hour7=[]
hour8=[]
hour9=[]
hour10=[]
hour11=[]
hour12=[]
hour13=[]
hour14=[]
hour15=[]
hour16=[]
hour17=[]
hour18=[]
hour19=[]
hour20=[]
hour21=[]
hour22=[]
hour23=[]
hour00=[]
for i in range(0,25):
    hour1.append(station_list_night[i].at_time('1:00:00'))
    hour2.append(station_list_night[i].at_time('2:00:00'))
    hour3.append(station_list_night[i].at_time('3:00:00'))
    hour4.append(station_list_night[i].at_time('4:00:00'))
    hour5.append(station_list_night[i].at_time('5:00:00'))
    hour6.append(station_list_night[i].at_time('6:00:00'))
    hour7.append(station_list_night[i].at_time('7:00:00'))
    hour8.append(station_list_night[i].at_time('8:00:00'))
    hour9.append(station_list_night[i].at_time('9:00:00'))
    hour10.append(station_list_day[i].at_time('10:00:00'))
    hour11.append(station_list_day[i].at_time('11:00:00'))
    hour12.append(station_list_day[i].at_time('12:00:00'))
    hour13.append(station_list_day[i].at_time('13:00:00'))
    hour14.append(station_list_day[i].at_time('14:00:00'))
    hour15.append(station_list_day[i].at_time('15:00:00'))
    hour16.append(station_list_day[i].at_time('16:00:00'))
    hour17.append(station_list_day[i].at_time('17:00:00'))
    hour18.append(station_list_day[i].at_time('18:00:00'))
    hour19.append(station_list_day[i].at_time('19:00:00'))
    hour20.append(station_list_day[i].at_time('20:00:00'))
    hour21.append(station_list_day[i].at_time('21:00:00'))
    hour22.append(station_list_day[i].at_time('22:00:00'))
    hour23.append(station_list_day[i].at_time('23:00:00'))
    hour00.append(station_list_day[i].at_time('00:00:00'))

# %%
# Define the data arrays for each hour (you could replace these with actual data lists)
hours_data = [hour00, hour1, hour2, hour3, hour4, hour5, hour6, hour7, hour8, hour9, 
              hour10, hour11, hour12, hour13, hour14, hour15, hour16, hour17, hour18, hour19,
              hour20, hour21, hour22, hour23]

# Define indices for each category
indices_urban = [11, 2, 5, 18, 23, 16, 0, 4, 14, 17]
indices_suburban = [3, 15, 1, 20, 22, 13, 21, 12]
indices_rural = [8, 9, 10, 6, 7, 19,24]

# Define the number of elements for each group
urban_count = 10
suburban_count = 8
rural_count = 7

# Create separate lists for urban, suburban, and rural averages
urban_averages = []
suburban_averages = []
rural_averages = []
hours = []

# Loop through each hour (from hour0 to hour23)
for i, hour_data in enumerate(hours_data):
    # Calculate sums for each category
    urban_sum = sum(hour_data[idx] for idx in indices_urban)
    suburban_sum = sum(hour_data[idx] for idx in indices_suburban)
    rural_sum = sum(hour_data[idx] for idx in indices_rural)
    
    # Calculate the averages
    urban_avg = urban_sum / urban_count
    suburban_avg = suburban_sum / suburban_count
    rural_avg = rural_sum / rural_count
    
    # Append the results to the corresponding lists
    urban_averages.append(urban_avg)
    suburban_averages.append(suburban_avg)
    rural_averages.append(rural_avg)
    hours.append(i)

# Now `urban_averages`, `suburban_averages`, and `rural_averages` contain the averages for each hour (0 to 23)
# Print the results

# %%
urbanhour00=urban_averages[0]
suburbanhour00=suburban_averages[0]
ruralhour00=rural_averages[0]

urbanhour1=urban_averages[1]
suburbanhour1=suburban_averages[1]
ruralhour1=rural_averages[1]

urbanhour2=urban_averages[2]
suburbanhour2=suburban_averages[2]
ruralhour2=rural_averages[2]

urbanhour3=urban_averages[3]
suburbanhour3=suburban_averages[3]
ruralhour3=rural_averages[3]

urbanhour4=urban_averages[4]
suburbanhour4=suburban_averages[4]
ruralhour4=rural_averages[4]

urbanhour5=urban_averages[5]
suburbanhour5=suburban_averages[5]
ruralhour5=rural_averages[5]

urbanhour6=urban_averages[6]
suburbanhour6=suburban_averages[6]
ruralhour6=rural_averages[6]

urbanhour7=urban_averages[7]
suburbanhour7=suburban_averages[7]
ruralhour7=rural_averages[7]

urbanhour8=urban_averages[8]
suburbanhour8=suburban_averages[8]
ruralhour8=rural_averages[8]

urbanhour9=urban_averages[9]
suburbanhour9=suburban_averages[9]
ruralhour9=rural_averages[9]

urbanhour10=urban_averages[10]
suburbanhour10=suburban_averages[10]
ruralhour10=rural_averages[10]

urbanhour11=urban_averages[11]
suburbanhour11=suburban_averages[11]
ruralhour11=rural_averages[11]

urbanhour12=urban_averages[12]
suburbanhour12=suburban_averages[12]
ruralhour12=rural_averages[12]

urbanhour13=urban_averages[13]
suburbanhour13=suburban_averages[13]
ruralhour13=rural_averages[13]

urbanhour14=urban_averages[14]
suburbanhour14=suburban_averages[14]
ruralhour14=rural_averages[14]

urbanhour15=urban_averages[15]
suburbanhour15=suburban_averages[15]
ruralhour15=rural_averages[15]

urbanhour16=urban_averages[16]
suburbanhour16=suburban_averages[16]
ruralhour16=rural_averages[16]

urbanhour17=urban_averages[17]
suburbanhour17=suburban_averages[17]
ruralhour17=rural_averages[17]

urbanhour18=urban_averages[18]
suburbanhour18=suburban_averages[18]
ruralhour18=rural_averages[18]

urbanhour19=urban_averages[19]
suburbanhour19=suburban_averages[19]
ruralhour19=rural_averages[19]

urbanhour20=urban_averages[20]
suburbanhour20=suburban_averages[20]
ruralhour20=rural_averages[20]

urbanhour21=urban_averages[21]
suburbanhour21=suburban_averages[21]
ruralhour21=rural_averages[21]

urbanhour22=urban_averages[22]
suburbanhour22=suburban_averages[22]
ruralhour22=rural_averages[22]

urbanhour23=urban_averages[23]
suburbanhour23=suburban_averages[23]
ruralhour23=rural_averages[23]

# %%
fcst18urban = [
    fcst18hour00urban, fcst18hour01urban, fcst18hour02urban, fcst18hour03urban, fcst18hour04urban,
    fcst18hour05urban, fcst18hour06urban, fcst18hour07urban, fcst18hour08urban, fcst18hour09urban,
    fcst18hour10urban, fcst18hour11urban, fcst18hour12urban, fcst18hour13urban, fcst18hour14urban,
    fcst18hour15urban, fcst18hour16urban, fcst18hour17urban, fcst18hour18urban, fcst18hour19urban,
    fcst18hour20urban, fcst18hour21urban, fcst18hour22urban, fcst18hour23urban
]

# %%
fcst18suburban = [
    fcst18hour00suburban, fcst18hour01suburban, fcst18hour02suburban, fcst18hour03suburban, fcst18hour04suburban,
    fcst18hour05suburban, fcst18hour06suburban, fcst18hour07suburban, fcst18hour08suburban, fcst18hour09suburban,
    fcst18hour10suburban, fcst18hour11suburban, fcst18hour12suburban, fcst18hour13suburban, fcst18hour14suburban,
    fcst18hour15suburban, fcst18hour16suburban, fcst18hour17suburban, fcst18hour18suburban, fcst18hour19suburban,
    fcst18hour20suburban, fcst18hour21suburban, fcst18hour22suburban, fcst18hour23suburban
]

# %%
fcst18rural = [
    fcst18hour00rural, fcst18hour01rural, fcst18hour02rural, fcst18hour03rural, fcst18hour04rural,
    fcst18hour05rural, fcst18hour06rural, fcst18hour07rural, fcst18hour08rural, fcst18hour09rural,
    fcst18hour10rural, fcst18hour11rural, fcst18hour12rural, fcst18hour13rural, fcst18hour14rural,
    fcst18hour15rural, fcst18hour16rural, fcst18hour17rural, fcst18hour18rural, fcst18hour19rural,
    fcst18hour20rural, fcst18hour21rural, fcst18hour22rural, fcst18hour23rural
]

# %%
fcst00urbanHW1=[]
fcst00suburbanHW1=[]
fcst00ruralHW1=[]

fcst00urbanHW2=[]
fcst00suburbanHW2=[]
fcst00ruralHW2=[]

fcst00urbanHW3=[]
fcst00suburbanHW3=[]
fcst00ruralHW3=[]

fcst00urbanHW4=[]
fcst00suburbanHW4=[]
fcst00ruralHW4=[]

fcst00urbanHW5=[]
fcst00suburbanHW5=[]
fcst00ruralHW5=[]

fcst00urbanHW6=[]
fcst00suburbanHW6=[]
fcst00ruralHW6=[]

fcst00urbanHW7=[]
fcst00suburbanHW7=[]
fcst00ruralHW7=[]

fcst00urbanHW8=[]
fcst00suburbanHW8=[]
fcst00ruralHW8=[]

for ii in range(0,24):
    fcst00urbanHW1.append(fcst18urban[ii][11:14]-273.15)
    fcst00suburbanHW1.append(fcst18suburban[ii][11:14]-273.15)
    fcst00ruralHW1.append(fcst18rural[ii][11:14]-273.15)
    
    fcst00urbanHW2.append(fcst18urban[ii][18:28]-273.15)
    fcst00suburbanHW2.append(fcst18suburban[ii][18:28]-273.15)
    fcst00ruralHW2.append(fcst18rural[ii][18:28]-273.15)
    
    fcst00urbanHW3.append(fcst18urban[ii][27:29]-273.15)
    fcst00suburbanHW3.append(fcst18suburban[ii][27:29]-273.15)
    fcst00ruralHW3.append(fcst18rural[ii][27:29]-273.15)
    
    fcst00urbanHW4.append(fcst18urban[ii][32:40]-273.15)
    fcst00suburbanHW4.append(fcst18suburban[ii][32:40]-273.15)
    fcst00ruralHW4.append(fcst18rural[ii][32:40]-273.15)
    
    fcst00urbanHW5.append(fcst18urban[ii][41:46]-273.15)
    fcst00suburbanHW5.append(fcst18suburban[ii][41:46]-273.15)
    fcst00ruralHW5.append(fcst18rural[ii][41:46]-273.15)
    
    fcst00urbanHW6.append(fcst18urban[ii][59:63]-273.15)
    fcst00suburbanHW6.append(fcst18suburban[ii][59:63]-273.15)
    fcst00ruralHW6.append(fcst18rural[ii][59:63]-273.15)
    
    fcst00urbanHW7.append(fcst18urban[ii][64:66]-273.15)
    fcst00suburbanHW7.append(fcst18suburban[ii][64:66]-273.15)
    fcst00ruralHW7.append(fcst18rural[ii][64:66]-273.15)
    
    fcst00urbanHW8.append(fcst18urban[ii][85:89]-273.15)
    fcst00suburbanHW8.append(fcst18suburban[ii][85:89]-273.15)
    fcst00ruralHW8.append(fcst18rural[ii][85:89]-273.15)

# %%
uhiHW1=[]
uhiHW2=[]
uhiHW3=[]
uhiHW4=[]
uhiHW5=[]
uhiHW6=[]
uhiHW7=[]
uhiHW8=[]
for ii in range(0,24):
    uhiHW1.append(fcst00urbanHW1[ii]-fcst00ruralHW1[ii])
    uhiHW2.append(fcst00urbanHW2[ii]-fcst00ruralHW2[ii])
    uhiHW3.append(fcst00urbanHW3[ii]-fcst00ruralHW3[ii])
    uhiHW4.append(fcst00urbanHW4[ii]-fcst00ruralHW4[ii])
    uhiHW5.append(fcst00urbanHW5[ii]-fcst00ruralHW5[ii])
    uhiHW6.append(fcst00urbanHW6[ii]-fcst00ruralHW6[ii])
    uhiHW7.append(fcst00urbanHW7[ii]-fcst00ruralHW7[ii])
    uhiHW8.append(fcst00urbanHW8[ii]-fcst00ruralHW8[ii])
    
    
for ii in range(0,23):
    cleaned_list1 = [x for x in uhiHW1[i] if not math.isnan(x)] 
    cleaned_list2 = [x for x in uhiHW1[i] if not math.isnan(x)]
    cleaned_list3 = [x for x in uhiHW1[i] if not math.isnan(x)]
    cleaned_list4 = [x for x in uhiHW1[i] if not math.isnan(x)]
    cleaned_list5 = [x for x in uhiHW1[i] if not math.isnan(x)]
    cleaned_list6 = [x for x in uhiHW1[i] if not math.isnan(x)]
    cleaned_list7 = [x for x in uhiHW1[i] if not math.isnan(x)]
    cleaned_list8 = [x for x in uhiHW1[i] if not math.isnan(x)]
#print(cleaned_list3)
averages=[]   
for ii in range(0,1):
    averages.append(np.average(cleaned_list1[ii]))
    averages.append(np.average(cleaned_list2[ii]))
    averages.append(np.average(cleaned_list3[ii]))
    averages.append(np.average(cleaned_list4[ii]))
    averages.append(np.average(cleaned_list5[ii]))
    averages.append(np.average(cleaned_list6[ii]))
    averages.append(np.average(cleaned_list7[ii]))
    averages.append(np.average(cleaned_list8[ii]))
print(np.average(averages))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8decedbba512> in <module>
#      19
#      20 for ii in range(0,23):
# ---> 21     cleaned_list1 = [x for x in uhiHW1[i] if not math.isnan(x)]
#      22     cleaned_list2 = [x for x in uhiHW1[i] if not math.isnan(x)]
#      23     cleaned_list3 = [x for x in uhiHW1[i] if not math.isnan(x)]
#
# <ipython-input-19-8decedbba512> in <listcomp>(.0)
#      19
#      20 for ii in range(0,23):
# ---> 21     cleaned_list1 = [x for x in uhiHW1[i] if not math.isnan(x)]
#      22     cleaned_list2 = [x for x in uhiHW1[i] if not math.isnan(x)]
#      23     cleaned_list3 = [x for x in uhiHW1[i] if not math.isnan(x)]
#
# NameError: name 'math' is not defined

# %%
# Heatwave 1 [12:15]
urbansHW1 = [urbanhour00[13:15], urbanhour1[13:15], urbanhour2[13:15], urbanhour3[13:15], urbanhour4[13:15], urbanhour5[13:15], urbanhour6[13:15], urbanhour7[13:15], urbanhour8[13:15], urbanhour9[13:15], urbanhour10[13:15], urbanhour11[13:15], urbanhour12[13:15], urbanhour13[13:15], urbanhour14[13:15], urbanhour15[13:15], urbanhour16[13:15], urbanhour17[13:15], urbanhour18[13:15], urbanhour19[13:15], urbanhour20[13:15], urbanhour21[13:15], urbanhour22[13:15], urbanhour23[13:15]]
suburbansHW1 = [suburbanhour00[12:15], suburbanhour1[12:15], suburbanhour2[12:15], suburbanhour3[12:15], suburbanhour4[12:15], suburbanhour5[12:15], suburbanhour6[12:15], suburbanhour7[12:15], suburbanhour8[12:15], suburbanhour9[12:15], suburbanhour10[12:15], suburbanhour11[12:15], suburbanhour12[12:15], suburbanhour13[12:15], suburbanhour14[12:15], suburbanhour15[12:15], suburbanhour16[12:15], suburbanhour17[12:15], suburbanhour18[12:15], suburbanhour19[12:15], suburbanhour20[12:15], suburbanhour21[12:15], suburbanhour22[12:15], suburbanhour23[12:15]]
ruralsHW1 = [ruralhour00[12:15], ruralhour1[12:15], ruralhour2[12:15], ruralhour3[12:15], ruralhour4[12:15], ruralhour5[12:15], ruralhour6[12:15], ruralhour7[12:15], ruralhour8[12:15], ruralhour9[12:15], ruralhour10[12:15], ruralhour11[12:15], ruralhour12[12:15], ruralhour13[12:15], ruralhour14[12:15], ruralhour15[12:15], ruralhour16[12:15], ruralhour17[12:15], ruralhour18[12:15], ruralhour19[12:15], ruralhour20[12:15], ruralhour21[12:15], ruralhour22[12:15], ruralhour23[12:15]]

# Heatwave 2 [19:27]
urbansHW2 = [urbanhour00[19:27], urbanhour1[19:27], urbanhour2[19:27], urbanhour3[19:27], urbanhour4[19:27], urbanhour5[19:27], urbanhour6[19:27], urbanhour7[19:27], urbanhour8[19:27], urbanhour9[19:27], urbanhour10[19:27], urbanhour11[19:27], urbanhour12[19:27], urbanhour13[19:27], urbanhour14[19:27], urbanhour15[19:27], urbanhour16[19:27], urbanhour17[19:27], urbanhour18[19:27], urbanhour19[19:27], urbanhour20[19:27], urbanhour21[19:27], urbanhour22[19:27], urbanhour23[19:27]]
suburbansHW2 = [suburbanhour00[19:27], suburbanhour1[19:27], suburbanhour2[19:27], suburbanhour3[19:27], suburbanhour4[19:27], suburbanhour5[19:27], suburbanhour6[19:27], suburbanhour7[19:27], suburbanhour8[19:27], suburbanhour9[19:27], suburbanhour10[19:27], suburbanhour11[19:27], suburbanhour12[19:27], suburbanhour13[19:27], suburbanhour14[19:27], suburbanhour15[19:27], suburbanhour16[19:27], suburbanhour17[19:27], suburbanhour18[19:27], suburbanhour19[19:27], suburbanhour20[19:27], suburbanhour21[19:27], suburbanhour22[19:27], suburbanhour23[19:27]]
ruralsHW2 = [ruralhour00[19:27], ruralhour1[19:27], ruralhour2[19:27], ruralhour3[19:27], ruralhour4[19:27], ruralhour5[19:27], ruralhour6[19:27], ruralhour7[19:27], ruralhour8[19:27], ruralhour9[19:27], ruralhour10[19:27], ruralhour11[19:27], ruralhour12[19:27], ruralhour13[19:27], ruralhour14[19:27], ruralhour15[19:27], ruralhour16[19:27], ruralhour17[19:27], ruralhour18[19:27], ruralhour19[19:27], ruralhour20[19:27], ruralhour21[19:27], ruralhour22[19:27], ruralhour23[19:27]]

# Heatwave 3 [28:30]
urbansHW3 = [urbanhour00[28:30], urbanhour1[28:30], urbanhour2[28:30], urbanhour3[28:30], urbanhour4[28:30], urbanhour5[28:30], urbanhour6[28:30], urbanhour7[28:30], urbanhour8[28:30], urbanhour9[28:30], urbanhour10[28:30], urbanhour11[28:30], urbanhour12[28:30], urbanhour13[28:30], urbanhour14[28:30], urbanhour15[28:30], urbanhour16[28:30], urbanhour17[28:30], urbanhour18[28:30], urbanhour19[28:30], urbanhour20[28:30], urbanhour21[28:30], urbanhour22[28:30], urbanhour23[28:30]]
suburbansHW3 = [suburbanhour00[28:30], suburbanhour1[28:30], suburbanhour2[28:30], suburbanhour3[28:30], suburbanhour4[28:30], suburbanhour5[28:30], suburbanhour6[28:30], suburbanhour7[28:30], suburbanhour8[28:30], suburbanhour9[28:30], suburbanhour10[28:30], suburbanhour11[28:30], suburbanhour12[28:30], suburbanhour13[28:30], suburbanhour14[28:30], suburbanhour15[28:30], suburbanhour16[28:30], suburbanhour17[28:30], suburbanhour18[28:30], suburbanhour19[28:30], suburbanhour20[28:30], suburbanhour21[28:30], suburbanhour22[28:30], suburbanhour23[28:30]]
ruralsHW3 = [ruralhour00[28:30], ruralhour1[28:30], ruralhour2[28:30], ruralhour3[28:30], ruralhour4[28:30], ruralhour5[28:30], ruralhour6[28:30], ruralhour7[28:30], ruralhour8[28:30], ruralhour9[28:30], ruralhour10[28:30], ruralhour11[28:30], ruralhour12[28:30], ruralhour13[28:30], ruralhour14[28:30], ruralhour15[28:30], ruralhour16[28:30], ruralhour17[28:30], ruralhour18[28:30], ruralhour19[28:30], ruralhour20[28:30], ruralhour21[28:30], ruralhour22[28:30], ruralhour23[28:30]]

# Heatwave 4 [33:41]
urbansHW4 = [urbanhour00[33:41], urbanhour1[33:41], urbanhour2[33:41], urbanhour3[33:41], urbanhour4[33:41], urbanhour5[33:41], urbanhour6[33:41], urbanhour7[33:41], urbanhour8[33:41], urbanhour9[33:41], urbanhour10[33:41], urbanhour11[33:41], urbanhour12[33:41], urbanhour13[33:41], urbanhour14[33:41], urbanhour15[33:41], urbanhour16[33:41], urbanhour17[33:41], urbanhour18[33:41], urbanhour19[33:41], urbanhour20[33:41], urbanhour21[33:41], urbanhour22[33:41], urbanhour23[33:41]]
suburbansHW4 = [suburbanhour00[33:41], suburbanhour1[33:41], suburbanhour2[33:41], suburbanhour3[33:41], suburbanhour4[33:41], suburbanhour5[33:41], suburbanhour6[33:41], suburbanhour7[33:41], suburbanhour8[33:41], suburbanhour9[33:41], suburbanhour10[33:41], suburbanhour11[33:41], suburbanhour12[33:41], suburbanhour13[33:41], suburbanhour14[33:41], suburbanhour15[33:41], suburbanhour16[33:41], suburbanhour17[33:41], suburbanhour18[33:41], suburbanhour19[33:41], suburbanhour20[33:41], suburbanhour21[33:41], suburbanhour22[33:41], suburbanhour23[33:41]]
ruralsHW4 = [ruralhour00[33:41], ruralhour1[33:41], ruralhour2[33:41], ruralhour3[33:41], ruralhour4[33:41], ruralhour5[33:41], ruralhour6[33:41], ruralhour7[33:41], ruralhour8[33:41], ruralhour9[33:41], ruralhour10[33:41], ruralhour11[33:41], ruralhour12[33:41], ruralhour13[33:41], ruralhour14[33:41], ruralhour15[33:41], ruralhour16[33:41], ruralhour17[33:41], ruralhour18[33:41], ruralhour19[33:41], ruralhour20[33:41], ruralhour21[33:41], ruralhour22[33:41], ruralhour23[33:41]]

# Heatwave 5 [50:60]
urbansHW5 = [urbanhour00[50:60], urbanhour1[50:60], urbanhour2[50:60], urbanhour3[50:60], urbanhour4[50:60], urbanhour5[50:60], urbanhour6[50:60], urbanhour7[50:60], urbanhour8[50:60], urbanhour9[50:60], urbanhour10[50:60], urbanhour11[50:60], urbanhour12[50:60], urbanhour13[50:60], urbanhour14[50:60], urbanhour15[50:60], urbanhour16[50:60], urbanhour17[50:60], urbanhour18[50:60], urbanhour19[50:60], urbanhour20[50:60], urbanhour21[50:60], urbanhour22[50:60], urbanhour23[50:60]]
suburbansHW5 = [suburbanhour00[50:60], suburbanhour1[50:60], suburbanhour2[50:60], suburbanhour3[50:60], suburbanhour4[50:60], suburbanhour5[50:60], suburbanhour6[50:60], suburbanhour7[50:60], suburbanhour8[50:60], suburbanhour9[50:60], suburbanhour10[50:60], suburbanhour11[50:60], suburbanhour12[50:60], suburbanhour13[50:60], suburbanhour14[50:60], suburbanhour15[50:60], suburbanhour16[50:60], suburbanhour17[50:60], suburbanhour18[50:60], suburbanhour19[50:60], suburbanhour20[50:60], suburbanhour21[50:60], suburbanhour22[50:60], suburbanhour23[50:60]]
ruralsHW5 = [ruralhour00[50:60], ruralhour1[50:60], ruralhour2[50:60], ruralhour3[50:60], ruralhour4[50:60], ruralhour5[50:60], ruralhour6[50:60], ruralhour7[50:60], ruralhour8[50:60], ruralhour9[50:60], ruralhour10[50:60], ruralhour11[50:60], ruralhour12[50:60], ruralhour13[50:60], ruralhour14[50:60], ruralhour15[50:60], ruralhour16[50:60], ruralhour17[50:60], ruralhour18[50:60], ruralhour19[50:60], ruralhour20[50:60], ruralhour21[50:60], ruralhour22[50:60], ruralhour23[50:60]]

#heatwave 6
urbansHW6 = [urbanhour00[65:74], urbanhour1[65:74], urbanhour2[65:74], urbanhour3[65:74], urbanhour4[65:74], urbanhour5[65:74], urbanhour6[65:74], urbanhour7[65:74], urbanhour8[65:74], urbanhour9[65:74], urbanhour10[65:74], urbanhour11[65:74], urbanhour12[65:74], urbanhour13[65:74], urbanhour14[65:74], urbanhour15[65:74], urbanhour16[65:74], urbanhour17[65:74], urbanhour18[65:74], urbanhour19[65:74], urbanhour20[65:74], urbanhour21[65:74], urbanhour22[65:74], urbanhour23[65:74]]
suburbansHW6 = [suburbanhour00[65:74], suburbanhour1[65:74], suburbanhour2[65:74], suburbanhour3[65:74], suburbanhour4[65:74], suburbanhour5[65:74], suburbanhour6[65:74], suburbanhour7[65:74], suburbanhour8[65:74], suburbanhour9[65:74], suburbanhour10[65:74], suburbanhour11[65:74], suburbanhour12[65:74], suburbanhour13[65:74], suburbanhour14[65:74], suburbanhour15[65:74], suburbanhour16[65:74], suburbanhour17[65:74], suburbanhour18[65:74], suburbanhour19[65:74], suburbanhour20[65:74], suburbanhour21[65:74], suburbanhour22[65:74], suburbanhour23[65:74]]
ruralsHW6 = [ruralhour00[65:74], ruralhour1[65:74], ruralhour2[65:74], ruralhour3[65:74], ruralhour4[65:74], ruralhour5[65:74], ruralhour6[65:74], ruralhour7[65:74], ruralhour8[65:74], ruralhour9[65:74], ruralhour10[65:74], ruralhour11[65:74], ruralhour12[65:74], ruralhour13[65:74], ruralhour14[65:74], ruralhour15[65:74], ruralhour16[65:74], ruralhour17[65:74], ruralhour18[65:74], ruralhour19[65:74], ruralhour20[65:74], ruralhour21[65:74], ruralhour22[65:74], ruralhour23[65:74]]

#heatwave 7
urbansHW7 = [urbanhour00[75:83], urbanhour1[75:83], urbanhour2[75:83], urbanhour3[75:83], urbanhour4[75:83], urbanhour5[75:83], urbanhour6[75:83], urbanhour7[75:83], urbanhour8[75:83], urbanhour9[75:83], urbanhour10[75:83], urbanhour11[75:83], urbanhour12[75:83], urbanhour13[75:83], urbanhour14[75:83], urbanhour15[75:83], urbanhour16[75:83], urbanhour17[75:83], urbanhour18[75:83], urbanhour19[75:83], urbanhour20[75:83], urbanhour21[75:83], urbanhour22[75:83], urbanhour23[75:83]]
suburbansHW7 = [suburbanhour00[75:83], suburbanhour1[75:83], suburbanhour2[75:83], suburbanhour3[75:83], suburbanhour4[75:83], suburbanhour5[75:83], suburbanhour6[75:83], suburbanhour7[75:83], suburbanhour8[75:83], suburbanhour9[75:83], suburbanhour10[75:83], suburbanhour11[75:83], suburbanhour12[75:83], suburbanhour13[75:83], suburbanhour14[75:83], suburbanhour15[75:83], suburbanhour16[75:83], suburbanhour17[75:83], suburbanhour18[75:83], suburbanhour19[75:83], suburbanhour20[75:83], suburbanhour21[75:83], suburbanhour22[75:83], suburbanhour23[75:83]]
ruralsHW7 = [ruralhour00[75:83], ruralhour1[75:83], ruralhour2[75:83], ruralhour3[75:83], ruralhour4[75:83], ruralhour5[75:83], ruralhour6[75:83], ruralhour7[75:83], ruralhour8[75:83], ruralhour9[75:83], ruralhour10[75:83], ruralhour11[75:83], ruralhour12[75:83], ruralhour13[75:83], ruralhour14[75:83], ruralhour15[75:83], ruralhour16[75:83], ruralhour17[75:83], ruralhour18[75:83], ruralhour19[75:83], ruralhour20[75:83], ruralhour21[75:83], ruralhour22[75:83], ruralhour23[75:83]]

#heatwave 8
urbansHW8 = [urbanhour00[90:98], urbanhour1[90:98], urbanhour2[90:98], urbanhour3[90:98], urbanhour4[90:98], urbanhour5[90:98], urbanhour6[90:98], urbanhour7[90:98], urbanhour8[90:98], urbanhour9[90:98], urbanhour10[90:98], urbanhour11[90:98], urbanhour12[90:98], urbanhour13[90:98], urbanhour14[90:98], urbanhour15[90:98], urbanhour16[90:98], urbanhour17[90:98], urbanhour18[90:98], urbanhour19[90:98], urbanhour20[90:98], urbanhour21[90:98], urbanhour22[90:98], urbanhour23[90:98]]
suburbansHW8 = [suburbanhour00[90:98], suburbanhour1[90:98], suburbanhour2[90:98], suburbanhour3[90:98], suburbanhour4[90:98], suburbanhour5[90:98], suburbanhour6[90:98], suburbanhour7[90:98], suburbanhour8[90:98], suburbanhour9[90:98], suburbanhour10[90:98], suburbanhour11[90:98], suburbanhour12[90:98], suburbanhour13[90:98], suburbanhour14[90:98], suburbanhour15[90:98], suburbanhour16[90:98], suburbanhour17[90:98], suburbanhour18[90:98], suburbanhour19[90:98], suburbanhour20[90:98], suburbanhour21[90:98], suburbanhour22[90:98], suburbanhour23[90:98]]
ruralsHW8 = [ruralhour00[90:98], ruralhour1[90:98], ruralhour2[90:98], ruralhour3[90:98], ruralhour4[90:98], ruralhour5[90:98], ruralhour6[90:98], ruralhour7[90:98], ruralhour8[90:98], ruralhour9[90:98], ruralhour10[90:98], ruralhour11[90:98], ruralhour12[90:98], ruralhour13[90:98], ruralhour14[90:98], ruralhour15[90:98], ruralhour16[90:98], ruralhour17[90:98], ruralhour18[90:98], ruralhour19[90:98], ruralhour20[90:98], ruralhour21[90:98], ruralhour22[90:98], ruralhour23[90:98]]

#coolwave 1 [9:12]
#coolwave 2 [30:33]
#coolwave 3 [47:50]
#coolwave 4 [53:56]
#coolwave 5 [71:75]
#coolwave 6 [77:85]

# %%
differenceHW1urban = []
differenceHW1suburban = []
differenceHW1rural = []

differenceHW2urban = []
differenceHW2suburban = []
differenceHW2rural = []

differenceHW3urban = []
differenceHW3suburban = []
differenceHW3rural = []

differenceHW4urban = []
differenceHW4suburban = []
differenceHW4rural = []

differenceHW5urban = []
differenceHW5suburban = []
differenceHW5rural = []

differenceHW6urban = []
differenceHW6suburban = []
differenceHW6rural = []

differenceHW7urban = []
differenceHW7suburban = []
differenceHW7rural = []

differenceHW8urban = []
differenceHW8suburban = []
differenceHW8rural = []

# Loop over each hour (assuming 24 hours)
for i in range(0, 23):
    # Heatwave 1 (range 0-9)
    differenceHW1urban.append(fcst00urbanHW1[i] - urbansHW1[i])
    differenceHW1suburban.append(fcst00suburbanHW1[i] - suburbansHW1[i])
    differenceHW1rural.append(fcst00ruralHW1[i] - ruralsHW1[i])
    
    # Heatwave 2 (range 10-19)
    differenceHW2urban.append(fcst00urbanHW2[i] - urbansHW2[i])
    differenceHW2suburban.append(fcst00suburbanHW2[i] - suburbansHW2[i])
    differenceHW2rural.append(fcst00ruralHW2[i] - ruralsHW2[i])
    
    # Heatwave 3 (range 20-29)
    differenceHW3urban.append(fcst00urbanHW3[i] - urbansHW3[i])
    differenceHW3suburban.append(fcst00suburbanHW3[i] - suburbansHW3[i])
    differenceHW3rural.append(fcst00ruralHW3[i] - ruralsHW3[i])
    
    # Heatwave 4 (range 30-39)
    differenceHW4urban.append(fcst00urbanHW4[i] - urbansHW4[i])
    differenceHW4suburban.append(fcst00suburbanHW4[i] - suburbansHW4[i])
    differenceHW4rural.append(fcst00ruralHW4[i] - ruralsHW4[i])
    
    # Heatwave 5 (range 40-49)
    differenceHW5urban.append(fcst00urbanHW5[i] - urbansHW5[i])
    differenceHW5suburban.append(fcst00suburbanHW5[i] - suburbansHW5[i])
    differenceHW5rural.append(fcst00ruralHW5[i] - ruralsHW5[i])
    
    # Heatwave 6 (range 65-74)
    differenceHW6urban.append(fcst00urbanHW6[i] - urbansHW6[i])
    differenceHW6suburban.append(fcst00suburbanHW6[i] - suburbansHW6[i])
    differenceHW6rural.append(fcst00ruralHW6[i] - ruralsHW6[i])
    
    # Heatwave 7 (range 75-83)
    differenceHW7urban.append(fcst00urbanHW7[i] - urbansHW7[i])
    differenceHW7suburban.append(fcst00suburbanHW7[i] - suburbansHW7[i])
    differenceHW7rural.append(fcst00ruralHW7[i] - ruralsHW7[i])
    
    # Heatwave 8 (range 90-98)
    differenceHW8urban.append(fcst00urbanHW8[i] - urbansHW8[i])
    differenceHW8suburban.append(fcst00suburbanHW8[i] - suburbansHW8[i])
    differenceHW8rural.append(fcst00ruralHW8[i] - ruralsHW8[i])

# %%
import math
listHW1urban=[]
listHW1suburban=[]
listHW1rural=[]

listHW2urban=[]
listHW2suburban=[]
listHW2rural=[]

listHW3urban=[]
listHW3suburban=[]
listHW3rural=[]

listHW4urban=[]
listHW4suburban=[]
listHW4rural=[]

listHW5urban=[]
listHW5suburban=[]
listHW5rural=[]

listHW6urban=[]
listHW6suburban=[]
listHW6rural=[]

listHW7urban=[]
listHW7suburban=[]
listHW7rural=[]

listHW8urban=[]
listHW8suburban=[]
listHW8rural=[]
for i in range(0,23):
    cleaned_list1 = [x for x in differenceHW1urban[i] if not math.isnan(x)]
    cleaned_list2 = [x for x in differenceHW1suburban[i] if not math.isnan(x)]
    cleaned_list3 = [x for x in differenceHW1rural[i] if not math.isnan(x)]
    
    cleaned_list4 = [x for x in differenceHW2urban[i] if not math.isnan(x)]
    cleaned_list5 = [x for x in differenceHW2suburban[i] if not math.isnan(x)]
    cleaned_list6 = [x for x in differenceHW2rural[i] if not math.isnan(x)]
    
    cleaned_list7 = [x for x in differenceHW3urban[i] if not math.isnan(x)]
    cleaned_list8 = [x for x in differenceHW3suburban[i] if not math.isnan(x)]
    cleaned_list9 = [x for x in differenceHW3rural[i] if not math.isnan(x)]
    
    cleaned_list10 = [x for x in differenceHW4urban[i] if not math.isnan(x)]
    cleaned_list11 = [x for x in differenceHW4suburban[i] if not math.isnan(x)]
    cleaned_list12 = [x for x in differenceHW4rural[i] if not math.isnan(x)]
    
    cleaned_list13 = [x for x in differenceHW5urban[i] if not math.isnan(x)]
    cleaned_list14 = [x for x in differenceHW5suburban[i] if not math.isnan(x)]
    cleaned_list15 = [x for x in differenceHW5rural[i] if not math.isnan(x)]
    
    cleaned_list16 = [x for x in differenceHW6urban[i] if not math.isnan(x)]
    cleaned_list17 = [x for x in differenceHW6suburban[i] if not math.isnan(x)]
    cleaned_list18 = [x for x in differenceHW6rural[i] if not math.isnan(x)]
    
    cleaned_list19 = [x for x in differenceHW7urban[i] if not math.isnan(x)]
    cleaned_list20 = [x for x in differenceHW7suburban[i] if not math.isnan(x)]
    cleaned_list21 = [x for x in differenceHW7rural[i] if not math.isnan(x)]
    
    cleaned_list22 = [x for x in differenceHW8urban[i] if not math.isnan(x)]
    cleaned_list23 = [x for x in differenceHW8suburban[i] if not math.isnan(x)]
    cleaned_list24 = [x for x in differenceHW8rural[i] if not math.isnan(x)]
    
    listHW1urban.append(cleaned_list1)
    listHW1suburban.append(cleaned_list2)
    listHW1rural.append(cleaned_list3)
    
    listHW2urban.append(cleaned_list4)
    listHW2suburban.append(cleaned_list5)
    listHW2rural.append(cleaned_list6)
    
    listHW3urban.append(cleaned_list7)
    listHW3suburban.append(cleaned_list8)
    listHW3rural.append(cleaned_list9)
    
    listHW4urban.append(cleaned_list10)
    listHW4suburban.append(cleaned_list11)
    listHW4rural.append(cleaned_list12)
    
    listHW5urban.append(cleaned_list13)
    listHW5suburban.append(cleaned_list14)
    listHW5rural.append(cleaned_list15)
    
    listHW6urban.append(cleaned_list16)
    listHW6suburban.append(cleaned_list17)
    listHW6rural.append(cleaned_list18)
    
    listHW7urban.append(cleaned_list19)
    listHW7suburban.append(cleaned_list20)
    listHW7rural.append(cleaned_list21)
    
    listHW8urban.append(cleaned_list22)
    listHW8suburban.append(cleaned_list23)
    listHW8rural.append(cleaned_list24)

# %%
import numpy as np

# Lists for storing averages
averageUrban = []
averageSuburban = []
averageRural = []

# Loop through each heatwave
for i in range(6, 23):
        # Create a list of the differences for each location and heatwave for the current time step
        urban_differences=(listHW1urban[i]+listHW2urban[i]+listHW3urban[i]+listHW4urban[i])
        averageUrban.append(urban_differences)
        suburban_differences=(listHW1suburban[i]+listHW2suburban[i]+listHW3suburban[i]+listHW4suburban[i])
        averageSuburban.append(suburban_differences)
        rural_differences=(listHW1rural[i]+listHW2rural[i]+listHW3rural[i]+listHW4rural[i])
        averageRural.append(rural_differences)
        
for i in range(0, 6):
        # Create a list of the differences for each location and heatwave for the current time step
        urban_differences=(listHW1urban[i]+listHW2urban[i]+listHW3urban[i]+listHW4urban[i])
        averageUrban.append(urban_differences)
        suburban_differences=(listHW1suburban[i]+listHW2suburban[i]+listHW3suburban[i]+listHW4suburban[i])
        averageSuburban.append(suburban_differences)
        rural_differences=(listHW1rural[i]+listHW2rural[i]+listHW3rural[i]+listHW4rural[i])
        averageRural.append(rural_differences)
    # Calculate the average, ignoring NaN values

# %%
fig, axes = plt.subplots(3, 1, figsize=(7, 10))  # 3 rows, 1 column

axes[0].boxplot(averageUrban)
axes[0].set_title('Urban - 18')
axes[0].set_ylim(-4,6)
axes[0].set_xlabel('Times (UTC)')
axes[0].set_ylabel('Temperature (C) (model-observations)')

axes[1].boxplot(averageSuburban)
axes[1].set_ylim(-4,6)
axes[1].set_title('Suburban - 18')
axes[1].set_xlabel('Times (UTC)')
axes[1].set_ylabel('Temperature (C) (model-observations)')

axes[2].boxplot(averageRural)
axes[2].set_ylim(-4,6)
axes[2].set_title('Rural - 18')
axes[2].set_xlabel('Time (UTC)')
axes[2].set_ylabel('Temperature (C) (model-observations)')

axes[0].axhline(y=0,ls='--',color='red')
axes[1].axhline(y=0,ls='--',color='red')
axes[2].axhline(y=0,ls='--',color='red')

plt.tight_layout()
plt.savefig('HeatwaveBoxplots18.png', dpi=1200)
plt.show()

# %%
total=[np.average(averageUrban[0])-np.average(averageRural[0]),np.average(averageUrban[1])-np.average(averageRural[1]),np.average(averageUrban[2])-np.average(averageRural[2]),np.average(averageUrban[3])-np.average(averageRural[3]),np.average(averageUrban[4])-np.average(averageRural[4])]
print(np.average(total))
# Out:
# -1.5730042261454658
